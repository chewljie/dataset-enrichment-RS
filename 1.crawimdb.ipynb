# %% [markdown]
# ## PRE PROCESS DATA
# Convert the movielens 100k data to csv file.

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline
import sklearn

# %%
u_cols = ['user_id', 'age', 'sex', 'occupation', 'zip_code']
r_cols = ['user_id', 'movie_id', 'rating', 'timestamp']
m_cols = ['movie_id', 'title', 'release_date', 'video_release_date', 'imdb_url']

# %%
users = pd.read_csv("ml-100k/u.user",sep='|',names=u_cols)
ratings = pd.read_csv('ml-100k/u.data',sep='\t', names=r_cols)
movies = pd.read_csv('ml-100k/u.item', sep='|', names=m_cols, usecols=range(5), encoding = "ISO-8859-1")

# %%
ratings.to_csv ('processed-data/dataratings.csv', index = None, header=True,encoding='utf-8')
movies.to_csv ('processed-data/movies.csv', index = None, header=True)
users.to_csv ('processed-data/users.csv', index = None, header=True)

# %% [markdown]
# ## Crawl from IMDB
# crawl more movie details form imdb website
#
# Step:
# 1. get imdb ID by search the movie name
# 2. get more movie details from omdbapi

# %%
import html5lib
import requests
import re
from bs4 import BeautifulSoup



class IMDB:
    baseUrl = "http://www.imdb.com/"
    titleUrl = baseUrl+"title/"
    searchUrl = baseUrl+"find?s=all&q="
    creditsPath = 'fullcredits/'
    currentSearchTitle = None
    
    
    def getMovie(self, title):
        return IMDB.getMovieByImdbId(self, IMDB.getIdFromName(self,title))
    
    def getMovieByImdbId(self, title):
        soup = IMDB.getSoup(title, None)
        movie = IMDB.getFeatures(soup);
        movie['rating'] = IMDB.getRatingByImdbId(self, title, soup)
        movie['summary'] = IMDB.getSummaryByImdbId(self, title, soup)
        movie['director'] = IMDB.getDirectorByImdbId(self, title, soup)
        movie['casting'] = IMDB.getCastingByImdbId(self, title)
        
        return movie;

    #############################
    '''get Ratings only STARTS'''
    #############################

    def getRating(self, title):
        return IMDB.getRatingByImdbId(self, IMDB.getIdFromName(title))

    def getRatingByImdbId(self, title, soup=None):
        soup = IMDB.getSoup(title, soup)
        return re.sub('\s+', '', IMDB.parseHTML(soup, 'div', 'class', 'ratingValue').strong.span.text)

    ###########################
    '''get Ratings only ENDS'''
    ###########################

    '''--------------------------------------------------------------------'''

    #############################
    '''get Summary only STARTS'''
    #############################

    def getSummary(self, title):
        return IMDB.getSummaryByImdbId(self, IMDB.getIdFromName(title))

    def getSummaryByImdbId(self, title, soup=None):
        soup = IMDB.getSoup(title, soup)
        return (re.sub(r'[\t\r\n]', '', (IMDB.parseHTML(soup, 'div', 'class', 'summary_text').text))).strip()

    #############################
    '''get Summary only ENDS'''
    #############################

    '''--------------------------------------------------------------------'''

    #############################
    '''get Director only STARTS'''
    #############################

    def getDirector(self, title):
        return IMDB.getDirectorByImdbId(self, IMDB.getIdFromName(title))

    def getDirectorByImdbId(self, title, soup=None):
        soup = IMDB.getSoup(title, soup)
        director = (re.sub(r'[\t\r\n]', '', (IMDB.parseHTML(soup, 'div', 'class', 'credit_summary_item').text))).strip()
        
        return director[9:]


    #############################
    '''get Director only ENDS'''
    #############################

    '''--------------------------------------------------------------------'''

    #############################
    '''get Casting only STARTS'''
    #############################

    def getCasting(self, title, length=10, all=False):
        return IMDB.getCastingByImdbId(self, IMDB.getIdFromName(title), length=length, all=all)

    def getCastingByImdbId(self, title, length=10, all=False):
        soup = IMDB.parseHTML(IMDB.scrapSite(IMDB.titleUrl+title+"/"+IMDB.creditsPath), 'table', 'class', 'cast_list')
        castList = []
        counter = 0;
        for tr in soup.find_all('tr'):
            tds = tr.find_all('td')
            if len(tds) > 2:
                cast = {}
                cast['actor'] = re.sub(r'[\t\r\n]', '', "".join(tds[1].find_all(text=True))).strip()
                cast['role'] = re.sub(r'[\t\r\n]', '', "".join(tds[3].find_all(text=True))).strip()
                castList.append(cast)
                if not all:
                    counter+=1;
                    if counter == 10:
                        break;
        return castList;

    #############################
    '''get Casting only ENDS'''
    #############################

    '''--------------------------------------------------------------------'''
    
    def getFeatures(soup):
        features = {}
        features['title'] = IMDB.currentSearchTitle
        '''features['runTime'] = re.sub(r'[\t\r\n]', '',IMDB.parseHTML(soup, 'time', 'datetime').text).strip()'''
        
        infobar = soup.find('div',{'class':'titleBar'})
        generDirty = infobar.findAll('a',{'href':True});
        features['runTime'] = re.sub(r'[\t\r\n]', '',infobar.find('time').text).strip();
        features['titleYear'] = generDirty[0].text
        features['releaseDate'] = re.sub(r'[\t\r\n]', '', generDirty[-1].text)
        gener = []
        for tag in generDirty:
            gener.append(tag.text)
        
        features['gener'] = gener[1:-1];
        features['posterUrl'] = IMDB.parseHTML(soup, 'div', 'class', 'poster').a.img['src']
        
        return features;
    
    def getSoup(title, soup):
        if soup is None:
            soup = IMDB.scrapSite(IMDB.titleUrl+title+"/")
        return soup;

    def parseHTML(soup, ele, idType, idValue):
        try:
            return soup.find( ele, {idType:idValue})
        except Exception:
            print("Sorry an error accured cant get data extracted")
        return ""

    def getIdFromName(self,title):
        try:
            soup = IMDB.scrapSite(IMDB.searchUrl+title)
            movie = soup.find('td',{'class':'result_text'}).a
            print("Movie: "+movie.text)
            IMDB.currentSearchTitle = movie.text;
            return movie['href'].split('/')[2]
        except Exception:
            print("Sorry an error accured cant get data extracted")
        
        return ""
    
    def getIdFromName2(self,title):
        try:
            soup = IMDB.scrapSite(IMDB.searchUrl+title)
            movie = soup.find('td',{'class':'result_text'}).a
            moviess = []
            moviess.append(movie.text)
            #print("Movie: "+movie.text)
            #print(moviess[0])
            IMDB.currentSearchTitle = movie.text;
            #print(movie['href'].split('/')[2])
            imdbID = movie['href'].split('/')[2]
            moviess.append(imdbID)
            return moviess;
        except Exception:
            return False
            #print("Sorry an error accured cant get data extracted")
        
        return ""

    def scrapSite(url):
        try:
            resp = requests.get(url)
            return BeautifulSoup(resp.text, "html5lib")
        except Exception:
            print("Problem with the network connection, please check your wifi or lan connection")

# %%
#test if works
imdb = IMDB()
movieName = 'Shanghai Triad '

imdb. getIdFromName2(movieName)
print(imdb. getIdFromName2(movieName))
# Out:
# ['Yao a yao, yao dao wai po qiao', 'tt0115012']

# %%
#expand original datafram to include imdbID and imdbName
movies['imdbID'] = 'N/A'
movies['imdbName'] = 'N/A'
movies.head()
# Out:
#    movie_id              title release_date  video_release_date  \
# 0         1   Toy Story (1995)  01-Jan-1995                 NaN
# 1         2   GoldenEye (1995)  01-Jan-1995                 NaN
# 2         3  Four Rooms (1995)  01-Jan-1995                 NaN
# 3         4  Get Shorty (1995)  01-Jan-1995                 NaN
# 4         5     Copycat (1995)  01-Jan-1995                 NaN
#
#                                             imdb_url imdbID imdbName
# 0  http://us.imdb.com/M/title-exact?Toy%20Story%2...    N/A      N/A
# 1  http://us.imdb.com/M/title-exact?GoldenEye%20(...    N/A      N/A
# 2  http://us.imdb.com/M/title-exact?Four%20Rooms%...    N/A      N/A
# 3  http://us.imdb.com/M/title-exact?Get%20Shorty%...    N/A      N/A
# 4  http://us.imdb.com/M/title-exact?Copycat%20(1995)    N/A      N/A

# %%
#iterate movie dataframe to obtain imdbID

for i, row in movies.iterrows():

    movieName = row['title']
    movieNameNoYear = movieName[:-7]
    
    imdbID = imdb. getIdFromName2(movieNameNoYear) 
    print(imdbID)
    if (imdbID):
        movies.loc[i,'imdbName']  = imdbID[0]
        movies.loc[i,'imdbID'] = imdbID[1]
    else:
        print("error for "+ movieName)
# Out:
# ['Toy Story', 'tt0114709']
# ['GoldenEye', 'tt0113189']
# ['Four Rooms', 'tt0113101']
# ['Get Shorty', 'tt5761496']
# ['Copycat', 'tt0112722']
# Sorry an error accured cant get data extracted
#
# error forShanghai Triad (Yao a yao yao dao waipo qiao) (1995)
# ['Twelve Monkeys', 'tt0114746']
# ['Babe', 'tt0112431']
# ['Dead Man Walking', 'tt0112818']
# ['Richard III', 'tt0114279']
# ['Se7en', 'tt0114369']
# ['The Usual Suspects', 'tt0114814']
# ['Mighty Aphrodite', 'tt0113819']
# ['Il postino', 'tt0110877']
# ["Mr. Holland's Opus", 'tt0113862']
# ['Gazon maudit', 'tt0113149']
# ['From Dusk Till Dawn', 'tt0116367']
# ['Badkonake sefid', 'tt0112445']
# ['Antonia', 'tt0112379']
# ['Angels and Insects', 'tt0112365']
# ['Muppet Treasure Island', 'tt0117110']
# ['Braveheart', 'tt0112573']
# ['Taxi Driver', 'tt0075314']
# ['Hung fan kui', 'tt0113326']
# ['The Birdcage', 'tt0115685']
# ['The Brothers McMullen', 'tt0112585']
# ['Bad Boys', 'tt0112442']
# ['Apollo 13', 'tt0112384']
# ['Batman Forever', 'tt0112462']
# ['Secret Diary of a Call Girl', 'tt1000734']
# ['Crimson Tide', 'tt0112740']
# ['Crumb', 'tt0109508']
# ['Desperado', 'tt0112851']
# ['The Doom Generation', 'tt0112887']
# ['Free Willy 2: The Adventure Home', 'tt0113114']
# ['Mad Love', 'tt0113729']
# ['Nadja', 'tt0110620']
# ['Haley Bennett', 'nm2247245']
# ['Strange Days', 'tt0114558']
# ['To Wong Foo Thanks for Everything, Julie Newmar', 'tt0114682']
# ['Billy Madison', 'tt0112508']
# ['Clerks', 'tt0109445']
# ['Disclosure', 'tt0109635']
# ['Dolores Claiborne', 'tt0109642']
# ['Yin shi nan nu', 'tt0111797']
# ['Exotica', 'tt0109759']
# ['Ed Wood', 'tt0109707']
# ['Hoop Dreams', 'tt0110057']
# ['I.Q.', 'tt0110099']
# ['Star Wars', 'tt0076759']
# ['Legends of the Fall', 'tt0110322']
# ['The Madness of King George', 'tt0110428']
# ['Natural Born Killers', 'tt0110632']
# ['Outbreak', 'tt0114069']
# ['Léon', 'tt0110413']
# ['Pulp Fiction', 'tt0110912']
# ['Priest', 'tt0822847']
# ['Quiz Show', 'tt0110932']
# ['Trois couleurs: Rouge', 'tt0111495']
# ['Trois couleurs: Bleu', 'tt0108394']
# ['Trois couleurs: Blanc', 'tt0111507']
# ['Stargate SG-1', 'tt0118480']
# ['The Santa Clause', 'tt0111070']
# ['The Shawshank Redemption', 'tt0111161']
# ["What's Eating Gilbert Grape", 'tt0108550']
# ['While You Were Sleeping', 'tt0114924']
# ['Ace Ventura: Pet Detective', 'tt0109040']
# ['Crow, the Pariah', 'tt5580008']
# ['Forrest Gump', 'tt0109830']
# ['Four Weddings and a Funeral', 'tt7587362']
# ['The Lion King', 'tt6105098']
# ['The Mask', 'tt0110475']
# ['Maverick', 'tt0110478']
# ['Faster, Pussycat! Kill! Kill!', 'tt0059170']
# ['Brother Minister: The Assassination of Malcolm X', 'tt0109339']
# ["Carlito's Way", 'tt0106519']
# ['The Firm', 'tt0106918']
# ['Free Willy', 'tt0106965']
# ['The Fugitive', 'tt0106977']
# ['Hot Shots! Part Deux', 'tt0107144']
# ['The Hudsucker Proxy', 'tt0110074']
# ['Jurassic Park', 'tt0107290']
# ['Much Ado About Nothing', 'tt0107616']
# ['The Puppet Masters', 'tt0111003']
# ['The Ref', 'tt0110955']
# ['The Remains of the Day', 'tt0107943']
# ['Searching for Bobby Fischer', 'tt0108065']
# ['Sleepless in Seattle', 'tt0108160']
# ['Blade Runner', 'tt0083658']
# ['So I Married an Axe Murderer', 'tt0108174']
# ['The Nightmare Before Christmas', 'tt0107688']
# ['True Romance', 'tt0108399']
# ['Welcome to the Dollhouse', 'tt0114906']
# ['Home Alone', 'tt0099785']
# ['Aladdin', 'tt6139732']
# ['Terminator 2: Judgment Day', 'tt0103064']
# ['Dances with Wolves', 'tt0099348']
# ['The Silence of the Lambs', 'tt0102926']
# ['Snow White and the Seven Dwarfs', 'tt0029583']
# ['Fargo', 'tt2802850']
# ['Heavy Metal', 'tt0082509']
# ['The AristoCats', 'tt0065421']
# ['All Dogs Go to Heaven 2', 'tt0115509']
# ['Theodore Rex', 'tt0114658']
# ['Sgt. Bilko', 'tt0117608']
# ['Les diaboliques', 'tt0046911']
# ['Moll Flanders', 'tt0117071']
# ['Kids in the Hall: Brain Candy', 'tt0116768']
# ['Mystery Science Theater 3000: The Movie', 'tt0117128']
# ['Operation Dumbo Drop', 'tt0114048']
# ['The Truth About Cats & Dogs', 'tt0117979']
# ['Flipper', 'tt0116322']
# ['Le hussard sur le toit', 'tt0113362']
# ['George Wallace', 'tt0119189']
# ['The Haunted World of Edward D. Wood Jr.', 'tt0113270']
# ['Cold Comfort Farm', 'tt0112701']
# ['Rock, the power of change', 'tt8300622']
# ['Twister', 'tt0117998']
# ['Maya Lin: A Strong Clear Vision', 'tt0110480']
# ['Striptease', 'tt0117765']
# ['Independence Day', 'tt0116629']
# ['The Cable Guy', 'tt0115798']
# ['The Frighteners', 'tt0116365']
# ['Lone Star', 'tt0116905']
# ['Phenomenon', 'tt0117333']
# ['The Spitfire Grill', 'tt0117718']
# ['The Godfather', 'tt0068646']
# ['Ging chaat goo si III: Chiu kup ging chaat', 'tt0104558']
# ['Bound', 'tt0115736']
# ['Kansas City', 'tt0116745']
# ["Breakfast at Tiffany's", 'tt0054698']
# ['The Wizard of Oz', 'tt0032138']
# ['Gone with the Wind', 'tt0031381']
# ['Citizen Kane', 'tt0033467']
# ['2001: A Space Odyssey', 'tt0062622']
# ['Mr. Smith Goes to Washington', 'tt0031679']
# ['Big Night', 'tt0115678']
# ['D3: The Mighty Ducks', 'tt0116000']
# ['The Love Bug', 'tt0064603']
# ['Homeward Bound: The Incredible Journey', 'tt0107131']
# ['20,000 Leagues Under the Sea', 'tt0046672']
# ['Bedknobs and Broomsticks', 'tt0066817']
# ['The Sound of Music', 'tt0059742']
# ['Die Hard', 'tt0095016']
# ['The Lawnmower Man', 'tt0104692']
# ['Unhook the Stars', 'tt0118044']
# ['The Long Kiss Goodnight', 'tt0116908']
# ['The Ghost and the Darkness', 'tt0116409']
# ['Judit Fekete', 'nm2436632']
# ['Swingers', 'tt0117802']
# ['Willy Wonka and the Chocolate Factory', 'tt1779540']
# ['Sleeper', 'tt0070707']
# ['A Fish Called Wanda', 'tt0095159']
# ['Life of Brian', 'tt0079470']
# ['Dirty Dancing', 'tt0092890']
# ['Reservoir Dogs', 'tt0105236']
# ['Platoon', 'tt0091763']
# ["Weekend at Bernie's", 'tt0098627']
# ['Basic Instinct', 'tt0103772']
# ['Glengarry Glen Ross', 'tt0104348']
# ['Top Gun', 'tt0092099']
# ['On Golden Pond', 'tt0082846']
# ['The Return of the Pink Panther', 'tt0072081']
# ['The Abyss', 'tt0096754']
# ['Jean de Florette', 'tt0091288']
# ['Manon des sources', 'tt0091480']
# ['Private Benjamin', 'tt0081375']
# ['Monty Python and the Holy Grail', 'tt0071853']
# ['The Wrong Trousers', 'tt0108598']
# ['Nuovo Cinema Paradiso', 'tt0095765']
# ['Delicatessen', 'tt0101700']
# ['Star Wars: Episode V - The Empire Strikes Back', 'tt0080684']
# ['The Princess Bride', 'tt0093779']
# ['Raiders of the Lost Ark', 'tt0082971']
# ['Brazil', 'tt0088846']
# ['Aliens', 'tt0090605']
# ['Il buono, il brutto, il cattivo', 'tt0060196']
# ['12 Angry Men', 'tt0050083']
# ['A Clockwork Orange', 'tt0066921']
# ['Apocalypse Now', 'tt0078788']
# ['Star Wars: Episode VI - Return of the Jedi', 'tt0086190']
# ['Goodfellas', 'tt0099685']
# ['Alien', 'tt0078748']
# ['Army of Darkness', 'tt0106308']
# ['Psycho', 'tt0054215']
# ['The Blues Brothers', 'tt0080455']
# ['The Godfather: Part II', 'tt0071562']
# ['Full Metal Jacket', 'tt0093058']
# ['A Grand Day Out', 'tt0104361']
# ['Henry V', 'tt0097499']
# ['Amadeus', 'tt0086879']
# ['Raging Bull', 'tt0081398']
# ['The Right Stuff', 'tt0086197']
# ['Sting, the White Shadow Dragon', 'tt10105216']
# ['Terminator, the Musical', 'tt3607066']
# ['Dead Poets Society', 'tt0097165']
# ['The Graduate', 'tt0061722']
# ['La Femme Nikita', 'tt0118379']
# ['The Bridge on the River Kwai', 'tt0050212']
# ['The Shining', 'tt0081505']
# ['Evil Dead II', 'tt0092991']
# ['Groundhog Day', 'tt0107048']
# ['Unforgiven', 'tt0105695']
# ['Back to the Future', 'tt0088763']
# ['Patton', 'tt0066206']
# ['Akira', 'tt0094625']
# ['Cyrano de Bergerac', 'tt0099334']
# ['Young Frankenstein', 'tt0072431']
# ['This Is Spinal Tap', 'tt0088258']
# ['Indiana Jones and the Last Crusade', 'tt0097576']
# ['M*A*S*H', 'tt0068098']
# ['The Unbearable Lightness of Being', 'tt0096332']
# ['A Room with a View', 'tt0091867']
# ['Pink Floyd: The Wall', 'tt0084503']
# ['Field of Dreams', 'tt0097351']
# ['When Harry Met Sally...', 'tt0098635']
# ['Dracula', 'tt0103874']
# ['Cape Fear', 'tt0101540']
# ['A Nightmare on Elm Street', 'tt0087800']
# ['The Mirror Has Two Faces', 'tt0117057']
# ['Breaking the Waves', 'tt0115751']
# ['Star Trek: First Contact', 'tt0117731']
# ['Sling Blade', 'tt0117666']
# ['Ridicule', 'tt0117477']
# ['101 Dalmatians', 'tt0115433']
# ['Die Hard 2', 'tt0099423']
# ['Star Trek VI: The Undiscovered Country', 'tt0102975']
# ['Star Trek II: The Wrath of Khan', 'tt0084726']
# ['Star Trek III: The Search for Spock', 'tt0088170']
# ['Star Trek IV: The Voyage Home', 'tt0092007']
# ['Batman Returns', 'tt0103776']
# ['Young Guns', 'tt0096487']
# ['Under Siege', 'tt0105690']
# ['Jaws', 'tt0073195']
# ['Mars Attacks!', 'tt0116996']
# ['Citizen Ruth', 'tt0115906']
# ['Jerry Maguire', 'tt0116695']
# ['Raising Arizona', 'tt0093822']
# ['Sneakers', 'tt0105435']
# ['Beavis and Butt-Head Do America', 'tt0115641']
# ['The Last of the Mohicans', 'tt0104691']
# ['Kolja', 'tt0116790']
# ['Jungle 2 Jungle', 'tt0119432']
# ["Smilla's Sense of Snow", 'tt0120152']
# ["The Devil's Own", 'tt0118972']
# ['Chasing Amy', 'tt0118842']
# ['Turbo: A Power Rangers Movie', 'tt0120389']
# ['Grosse Pointe Blank', 'tt0119229']
# ['Austin Powers: International Man of Mystery', 'tt0118655']
# ['The Fifth Element', 'tt0119116']
# ['Shall We Dance', 'tt0358135']
# ['The Lost World: Jurassic Park', 'tt0119567']
# ['The Pillow Book', 'tt0114134']
# ['Batman', 'tt0096895']
# ["My Best Friend's Wedding", 'tt0119738']
# ['Chacun cherche son chat', 'tt0115856']
# ['Men in Black', 'tt0119654']
# ['Arrival', 'tt2543164']
# ['George of the Jungle', 'tt0119190']
# ['Event Horizon', 'tt0119081']
# ['Air Bud', 'tt0118570']
# ['In the Company of Men', 'tt0119361']
# ['Kevin Nash', 'nm0621760']
# ['Mimic', 'tt0119675']
# ['The Hunt for Red October', 'tt0099810']
# ['Kull the Conqueror', 'tt0119484']
# Sorry an error accured cant get data extracted
#
# error forunknown
# ['Chasing Amy', 'tt0118842']
# ['The Full Monty', 'tt0119164']
# ['Gattaca', 'tt0119177']
# ['Starship Troopers', 'tt0120201']
# ['Good Will Hunting', 'tt0119217']
# ['Heat', 'tt0113277']
# ['Sabrina, the Teenage Witch', 'tt0115341']
# ['Sense and Sensibility', 'tt0114388']
# ['Leaving Las Vegas', 'tt0113627']
# ['Restoration', 'tt0114272']
# ['Bed of Roses', 'tt0115644']
# ['Once Upon a Time... When We Were Colored', 'tt0114039']
# ['Up Close and Personal', 'tt0497080']
# ['The River Wild', 'tt0110997']
# ['A Time to Kill', 'tt0117913']
# ['Emma', 'tt9214832']
# ['Steve Talley', 'nm1883440']
# ['A Thousand Acres', 'tt0120323']
# ['The English Patient', 'tt0116209']
# ["Marvin's Room", 'tt0116999']
# ['Scream', 'tt0117571']
# ['Evita', 'tt0116250']
# ['Fierce Creatures', 'tt0119115']
# ['Absolute Power', 'tt0118548']
# ['Rosewood', 'tt4465472']
# ['Donnie Brasco', 'tt0119008']
# ['Liar Liar', 'tt0119528']
# ['Breakdown', 'tt0118771']
# ['La promesse', 'tt0984632']
# ["Ulee's Gold", 'tt0120402']
# ['Face/Off', 'tt0119094']
# ['Hoodlum', 'tt0119311']
# ['Air Force One', 'tt0118571']
# ['High', 'tt0176813']
# ['L.A. Confidential', 'tt0119488']
# ["Ulee's Gold", 'tt0120402']
# ['Fly Away Home', 'tt0116329']
# ['The Ice Storm', 'tt0119349']
# ['Mrs Brown', 'tt0119280']
# ["The Devil's Advocate", 'tt0118971']
# ['FairyTale: A True Story', 'tt0119095']
# ['Deceiver', 'tt0119527']
# ['The Rainmaker', 'tt0119978']
# ['The Wings of the Dove', 'tt0120520']
# ['Midnight in the Garden of Good and Evil', 'tt0119668']
# ['Titanic', 'tt0120338']
# ['3 Ninjas: High Noon at Mega Mountain', 'tt0118539']
# ['Apt Pupil', 'tt0118636']
# ['As Good as It Gets', 'tt0119822']
# ['In the Name of the Father', 'tt0107207']
# ["Schindler's List", 'tt0108052']
# ['Everyone Says I Love You', 'tt0116242']
# ['Paradise Lost: The Child Murders at Robin Hood Hills', 'tt0117293']
# ['I Am Mother', 'tt6292852']
# ['Murder at 1600', 'tt0119731']
# ["Dante's Peak", 'tt0118928']
# ['Lost Highway', 'tt0116922']
# ['Crash', 'tt0375679']
# ['G.I. Jane', 'tt0119173']
# ['Cop Land', 'tt0118887']
# ['Conspiracy Theory', 'tt0118883']
# ['Desperate Measures', 'tt0118966']
# ['One Eight Seven', 'tt0118531']
# ['Edge of Tomorrow', 'tt1631867']
# ['Kiss the Girls', 'tt0119468']
# ['Game of Thrones', 'tt0944947']
# ['U Turn', 'tt0120399']
# ['How to Be a Player', 'tt0119326']
# ['Playing God', 'tt0119906']
# ['The House of Yes', 'tt0119324']
# ['Bean', 'tt0118689']
# ['Mad City', 'tt0119592']
# ['Boogie Nights', 'tt0118749']
# ['Critical Care', 'tt0118901']
# ['The Man Who Knew Too Little', 'tt0120483']
# ['Alien Resurrection', 'tt0118583']
# ['Apostle', 'tt6217306']
# ['Deconstructing Harry', 'tt0118954']
# ['Jackie Brown', 'tt0119396']
# ['Wag the Dog', 'tt0120885']
# ['Desperate Measures', 'tt0118966']
# ['Hard Rain', 'tt0120696']
# ['Fallen', 'tt0119099']
# ['The Prophecy II', 'tt0118643']
# ['Spice World', 'tt0120185']
# ['Deep Rising', 'tt0118956']
# ['The Wedding Singer', 'tt0120888']
# ['Sphere', 'tt0120184']
# ['The Client', 'tt0109446']
# ["One Flew Over the Cuckoo's Nest", 'tt0073486']
# ['Spawn', 'tt0120177']
# ['The Assignment', 'tt5034474']
# ['Spenser Confidential', 'tt8629748']
# ['Incognito', 'tt0119365']
# ['Blues Brothers 2000', 'tt0118747']
# ['Sudden Death', 'tt0114576']
# ['Ace Ventura: When Nature Calls', 'tt0112281']
# ['Powder', 'tt0114168']
# ['Dangerous Minds', 'tt0112792']
# ['Clueless', 'tt0112697']
# ['Bio-Dome', 'tt0115683']
# ['Bad Company', 'tt0280486']
# ['Mary Reilly', 'tt0117002']
# ['The Bridges of Madison County', 'tt0112579']
# ['Jeffrey', 'tt0113464']
# ['Dredd', 'tt1343727']
# ['Mighty Morphin Power Rangers: The Movie', 'tt0113820']
# ['Showgirls', 'tt0114436']
# ['Houseguest', 'tt0110066']
# ['Heavyweights', 'tt0110006']
# ['Miracle on 34th Street', 'tt0110527']
# ['Tales from the Crypt: Demon Knight', 'tt0114608']
# ['Star Trek: Generations', 'tt0111280']
# ["Muriel's Wedding", 'tt0110598']
# ['The Adventures of Priscilla, Queen of the Desert', 'tt0109045']
# ['The Flintstones', 'tt0109813']
# ['Naked Gun 33 1/3: The Final Insult', 'tt0110622']
# ['True Lies', 'tt0111503']
# ['Addams Family Values', 'tt0106220']
# ['The Age of Innocence', 'tt0106226']
# ['Beverly Hills Cop III', 'tt0109254']
# ['Black Beauty', 'tt8484160']
# ['Fear of a Black Hat', 'tt0106880']
# ['Last Action Hero', 'tt0107362']
# ['The Man Without a Face', 'tt0107501']
# ['Mrs. Doubtfire', 'tt0107614']
# ['Radioland Murders', 'tt0110939']
# ['Robin Hood: Men in Tights', 'tt0107977']
# ['Serial Mom', 'tt0111127']
# ['Striking Distance', 'tt0108238']
# ['Super Mario Bros.', 'tt0108255']
# ['The Three Musketeers', 'tt1509767']
# ['The Little Rascals', 'tt0110366']
# ['The Brady Bunch Movie', 'tt0112572']
# ['Ghost', 'tt0099653']
# ['Batman', 'tt0096895']
# ['Pinocchio', 'tt8333746']
# ['Mission: Impossible', 'tt0117060']
# ['Thinner', 'tt0117894']
# ['Spy Hard', 'tt0117723']
# ['A Close Shave', 'tt0112691']
# ['Jack', 'tt0116669']
# ['Kingpin', 'tt0116778']
# ['The Nutty Professor', 'tt0117218']
# ['A Very Brady Sequel', 'tt0118073']
# ['Bordello of Blood', 'tt0117826']
# ['My Favorite Year', 'tt0084370']
# ['The Apple Dumpling Gang', 'tt0072653']
# ['Old Yeller', 'tt0050798']
# ['The Parent Trap', 'tt0120783']
# ['Cinderella', 'tt1661199']
# ['Mary Poppins', 'tt0058331']
# ['Alice in Wonderland', 'tt1014759']
# ['Romeo and Juliet', 'tt0063518']
# ['Aladdin and the King of Thieves', 'tt0115491']
# ['E.T. the Extra-Terrestrial', 'tt0083866']
# ['Children of the Corn: The Gathering', 'tt0115885']
# ['Bob Roberts', 'tt0103850']
# ['Transformers: The Movie, The Parody', 'tt4597486']
# ['To Kill a Mockingbird', 'tt0056592']
# ['Harold and Maude', 'tt0067185']
# ['The Day the Earth Stood Still', 'tt0970416']
# ['Duck Soup', 'tt0023969']
# ['Highlander', 'tt0091203']
# ['Fantasia', 'tt0032455']
# ['Heathers', 'tt0097493']
# ['Forbidden Planet', 'tt0049223']
# ['Butch Cassidy and the Sundance Kid', 'tt0064115']
# ['An American Werewolf in London', 'tt0082010']
# ["Amityville 1992: It's About Time", 'tt0103678']
# ['Amityville 3-D', 'tt0085159']
# ['Amityville: A New Generation', 'tt0106262']
# ['Amityville II: The Possession', 'tt0083550']
# ['The Amityville Horror', 'tt0384806']
# ['The Amityville Curse', 'tt0099030']
# ['Birds of Prey: And the Fantabulous Emancipation of One Harley Quinn', 'tt7713068']
# ['The Blob', 'tt0094761']
# ['Body Snatchers', 'tt0106452']
# ['Burnt Offerings', 'tt0074258']
# ['Carrie', 'tt0074285']
# ['Good Omens', 'tt1869454']
# ['Star Trek: The Motion Picture', 'tt0079945']
# ['Star Trek V: The Final Frontier', 'tt0098382']
# ['Grease', 'tt0077631']
# ['Jaws 2', 'tt0077766']
# ['Jaws 3-D', 'tt0085750']
# ['Bastard Out of Carolina', 'tt0115633']
# ['Ging chaat goo si 4: Gaan dan yam mo', 'tt0116704']
# ['Beverly Hills Ninja', 'tt0118708']
# ['Free Willy 3: The Rescue', 'tt0119152']
# ['Nixon', 'tt0113987']
# ['Cry, the Beloved Country', 'tt0112749']
# ['The Crossing Guard', 'tt0112744']
# ['Rory Calhoun', 'nm0001983']
# ['Como agua para chocolate', 'tt0103994']
# ['The Secret of Roan Inish', 'tt0111112']
# ['Vanya on 42nd Street', 'tt0111590']
# ['The Jungle Book', 'tt3040964']
# ['Red Rock West', 'tt0105226']
# ['A Bronx Tale', 'tt0106489']
# ['Rudy', 'tt0108002']
# ['Short Cuts', 'tt0108122']
# ['Tombstone', 'tt0108358']
# ['Courage Under Fire', 'tt0115956']
# ['DragonHeart', 'tt0116136']
# ['James and the Giant Peach', 'tt0116683']
# ['Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb', 'tt0057012']
# ['Trainspotting', 'tt0117951']
# ['The First Wives Club', 'tt0116313']
# ['Matilda', 'tt0117008']
# ['The Philadelphia Story', 'tt0032904']
# ['Vertigo', 'tt0052357']
# ['North by Northwest', 'tt0053125']
# ['The Apartment', 'tt0053604']
# ['Some Like It Hot', 'tt0053291']
# ['Casablanca', 'tt0034583']
# ['The Maltese Falcon', 'tt0033870']
# ['My Fair Lady', 'tt0058385']
# ['Sabrina, the Teenage Witch', 'tt0115341']
# ['Roman Holiday', 'tt0046250']
# ['Sunset Blvd.', 'tt0043014']
# ['Notorious', 'tt0038787']
# ['To Catch a Thief', 'tt0048728']
# ['The Adventures of Robin Hood', 'tt0029843']
# ['East of Eden', 'tt0048028']
# ['The Thin Man', 'tt0025878']
# ['His Girl Friday', 'tt0032599']
# ['Around the World in 80 Days', 'tt0327437']
# ["It's a Wonderful Life", 'tt0038650']
# ['Bringing Up Baby', 'tt0029947']
# ['The African Queen', 'tt0043265']
# ['Cat on a Hot Tin Roof', 'tt0051459']
# ['Fly Away Home', 'tt0116329']
# ['Dumbo', 'tt3861390']
# ['Bananas', 'tt0066808']
# ['El reino', 'tt7095482']
# ['Bonnie and Clyde', 'tt0061418']
# ['A Perfect Murder', 'tt0120787']
# ['Rebel Without a Cause', 'tt0048545']
# ['A Streetcar Named Desire', 'tt0044081']
# ['The People vs. Larry Flynt', 'tt0117318']
# ['My Left Foot: The Story of Christy Brown', 'tt0097937']
# ['The Magnificent Seven', 'tt2404435']
# ['Lawrence of Arabia', 'tt0056172']
# ['Der Himmel über Berlin', 'tt0093191']
# ['The Third Man', 'tt0041959']
# ['Annie Hall', 'tt0075686']
# ['Das Boot', 'tt5830254']
# ['Local Hero', 'tt0085859']
# ['Thor', 'tt0800369']
# ["Miller's Crossing", 'tt0100150']
# ['The Treasure of the Sierra Madre', 'tt0040897']
# ['The Great Escape', 'tt0057115']
# ['The Deer Hunter', 'tt0077416']
# ['Down by Law', 'tt0090967']
# ['Cool Hand Luke', 'tt0061512']
# ['The Great Dictator', 'tt0032553']
# ['The Big Sleep', 'tt0038355']
# ['Ben-Hur', 'tt0052618']
# ['Gandhi', 'tt0083987']
# ['The Killing Fields', 'tt0087553']
# ['Mitt liv som hund', 'tt0089606']
# ['The Kid Who Would Be King', 'tt6811018']
# ['Shine', 'tt0117631']
# ['Kama Sutra: A Tale of Love', 'tt0116743']
# ['The Daytrippers', 'tt0116041']
# ['Traveller', 'tt0120366']
# ['Addicted to Love', 'tt0118556']
# ['Ponette', 'tt0117359']
# ['My Own Private Idaho', 'tt0102494']
# ['Anastasia', 'tt0118617']
# ['Mouse Hunt', 'tt11585520']
# ['Money Train', 'tt0113845']
# ['Mortal Kombat', 'tt0293429']
# ['Pocahontas', 'tt0114148']
# ['Les Misérables', 'tt1707386']
# ["Things to Do in Denver When You're Dead", 'tt0114660']
# ['Vampire in Brooklyn', 'tt0114825']
# ['Broken Arrow', 'tt0115759']
# ["The Young Poisoner's Handbook", 'tt0115033']
# ['Die unendliche Geschichte III: Rettung aus Phantasien', 'tt0110647']
# ['Rob Roy', 'tt0114287']
# ['Die Hard: With a Vengeance', 'tt0112864']
# ['Lord of Illusions', 'tt0113690']
# ['Species', 'tt0114508']
# ['A Walk in the Clouds', 'tt0114887']
# ['Waterworld', 'tt0114898']
# ["White Man's Burden", 'tt0114928']
# ['Bill Paxton', 'nm0000200']
# ['Farinelli', 'tt0109771']
# ['Heavenly Creatures', 'tt0110005']
# ['Interview with the Vampire: The Vampire Chronicles', 'tt0110148']
# ["A Kid in King Arthur's Court", 'tt0113538']
# ['Frankenstein', 'tt0109836']
# ['The Quick and the Dead', 'tt0114214']
# ['The Langoliers', 'tt0112040']
# ['Tales from the Hood', 'tt0114609']
# ['Village of the Damned', 'tt0114852']
# ['Clear and Present Danger', 'tt0109444']
# ["Wes Craven's New Nightmare", 'tt0111686']
# ['Speed', 'tt0111257']
# ['Wolf', 'tt0111742']
# ['Wyatt Earp', 'tt0111756']
# ['Another Stakeout', 'tt0106292']
# ['Blown Away', 'tt0109303']
# ['Body Snatchers', 'tt0106452']
# ['Boxing Helena', 'tt0106471']
# ["City Slickers II: The Legend of Curly's Gold", 'tt0109439']
# ['Cliffhanger', 'tt0106582']
# ['Coneheads', 'tt0106598']
# ['Demolition Man', 'tt0106697']
# ['Fatal Instinct', 'tt0106873']
# ['The Englishman Who Went Up a Hill But Came Down a Mountain', 'tt0112966']
# ['Kalifornia', 'tt0107302']
# ['The Piano', 'tt0107822']
# ['Romeo Is Bleeding', 'tt0107983']
# ['Sikeurit Gadeun', 'tt1841321']
# ['Son in Law', 'tt0108186']
# ['Terminal Velocity', 'tt0111400']
# ['The Hour of the Pig', 'tt5494894']
# ['Beauty and the Beast', 'tt2771200']
# ['The Wild Bunch', 'tt0065214']
# ['Hellraiser: Bloodline', 'tt0116514']
# ['Primal Fear', 'tt0117381']
# ['True Crime', 'tt0139668']
# ['Enemy at the Gates', 'tt0215750']
# ['Heavy', 'tt0113280']
# ['Dakota Fanning', 'nm0266824']
# ['The Hunchback of Notre Dame', 'tt0116583']
# ['Eraser', 'tt0116213']
# ['The Big Squeeze', 'tt0115680']
# ['Chiu kup gai wak', 'tt0106544']
# ['Robinson Crusoe', 'tt0117496']
# ['For Whom the Bell Tolls', 'tt0035896']
# ['An American in Paris', 'tt0043278']
# ['Rear Window', 'tt0047396']
# ['It Happened One Night', 'tt0025316']
# ['Meet Me in St. Louis', 'tt0037059']
# ['All About Eve', 'tt0042192']
# ['Rebecca', 'tt0032976']
# ['Spellbound', 'tt0038109']
# ['Father of the Bride', 'tt0101862']
# ['Ginnifer Goodwin', 'nm0329481']
# ['Laura', 'tt0037008']
# ['Lost Horizon', 'tt0029162']
# ['My Man Godfrey', 'tt0028010']
# ['Giant', 'tt0049261']
# ['The 39 Steps', 'tt0026029']
# ['Night of the Living Dead', 'tt0063350']
# ['Der blaue Engel', 'tt0020697']
# ['Picnic', 'tt0048491']
# ['Extreme Measures', 'tt0116259']
# ['Justin Chambers', 'nm0150362']
# ['Davy Crockett: King of the Wild Frontier', 'tt0047977']
# ['Swiss Family Robinson', 'tt0054357']
# ['Angels in the Outfield', 'tt0109127']
# ['The Three Caballeros', 'tt0038166']
# ['The Sword in the Stone', 'tt0057546']
# ['So Dear to My Heart', 'tt0041890']
# ['Robin Hood: Prince of Thieves', 'tt0102798']
# ['Sleepers', 'tt0117665']
# ['Victor Victoria', 'tt0084865']
# ['The Great Race', 'tt0059243']
# ['The Crying Game', 'tt0104036']
# ["Sophie's Choice", 'tt0084707']
# ['A Christmas Carol', 'tt7686464']
# ["Microcosmos: Le peuple de l'herbe", 'tt0117040']
# ['The Fog', 'tt0080749']
# ['Escape from New York', 'tt0082340']
# ['The Howling', 'tt0082533']
# ['Le retour de Martin Guerre', 'tt0084589']
# ['Die Blechtrommel', 'tt0078875']
# ['The Cook, the Thief, His Wife & Her Lover', 'tt0097108']
# ['Paths of Glory', 'tt0050825']
# ['The Grifters', 'tt0099703']
# ["L'innocente", 'tt0074686']
# ['The Thin Blue Line', 'tt0112194']
# ['Paris Is Burning', 'tt0100332']
# ['Once Upon a Time in the West', 'tt0064116']
# ['Ran', 'tt0089881']
# ['The Quiet Man', 'tt0045061']
# ['Once Upon a Time in America', 'tt0087843']
# ['Det sjunde inseglet', 'tt0050976']
# ['Glory', 'tt0097441']
# ['Rosencrantz and Guildenstern are Dead, and Absurd', 'tt5932256']
# ['Touch of Evil', 'tt0052311']
# ['Chinatown', 'tt0071315']
# ['Stand by Me', 'tt0092005']
# ['Misty Rosas', 'nm0741103']
# ['The Manchurian Candidate', 'tt0368008']
# ['Pump Up the Volume', 'tt0100436']
# ['Arsenic and Old Lace', 'tt0036613']
# ['Fried Green Tomatoes', 'tt0101921']
# ['High Noon', 'tt0044706']
# ['Somewhere in Time', 'tt0081534']
# ['Being There', 'tt0078841']
# ['Paris, Texas', 'tt0087884']
# ['Alien³', 'tt0103644']
# ['Blood for Dracula', 'tt0071233']
# ['Audrey Rose', 'tt0075704']
# ['Blood Beach', 'tt0082083']
# ['Body Parts', 'tt0101492']
# ['Body Snatchers', 'tt0106452']
# ['Bride of Frankenstein', 'tt0026138']
# ['Candyman', 'tt9347730']
# ['Cape Fear', 'tt0101540']
# ['Cat People', 'tt0083722']
# ['Nosferatu', 'tt0013442']
# ['The Crucible', 'tt0115988']
# ['Volcano: Fire on the Mountain', 'tt0120462']
# ['Volcano', 'tt0120461']
# ['Conan the Barbarian', 'tt0816462']
# ['Kull the Conqueror', 'tt0119484']
# ['Wishmaster', 'tt0120524']
# ['I Know What You Did Last Summer', 'tt0119345']
# ['RocketMan', 'tt0120029']
# ['In the Line of Fire', 'tt0107206']
# ['Executive Decision', 'tt0116253']
# ['A Perfect World', 'tt0107808']
# ["McHale's Navy", 'tt0055689']
# ['Leave It to Beaver', 'tt0050032']
# ['The Jackal', 'tt0119395']
# ['Seven Years in Tibet', 'tt0120102']
# ['Dark City', 'tt0118929']
# ['The American President', 'tt0112346']
# ['Casino', 'tt0112641']
# ['Persuasion', 'tt0844330']
# ['Kicking and Screaming', 'tt0113537']
# ['City Hall', 'tt0115907']
# ['The Basketball Diaries', 'tt0112461']
# ['The Browning Version', 'tt0109340']
# ['Little Women', 'tt3281548']
# ['Miami Rhapsody', 'tt0113808']
# ['Die Macht der Bilder: Leni Riefenstahl', 'tt0107472']
# ['Barcelona', 'tt0109219']
# ["Widows' Peak", 'tt0111712']
# ['The House of the Spirits', 'tt0107151']
# ["Singin' in the Rain", 'tt0045152']
# ['Bad Moon', 'tt0115610']
# ['Enchanted April', 'tt0101811']
# ['Sex, Lies, and Videotape', 'tt0098724']
# ['Strictly Ballroom', 'tt0105488']
# ['Better Off Dead...', 'tt0088794']
# ['The Substance of Fire', 'tt0117773']
# ['Tin Men', 'tt0094155']
# ['O', 'tt0184791']
# ['Carrington', 'tt0112637']
# ['To Die For', 'tt0114681']
# ['Home for the Holidays', 'tt0113321']
# ['The Juror', 'tt0116731']
# ['In the Bleak Midwinter', 'tt0113403']
# ['Canadian Bacon', 'tt0109370']
# ['First Knight', 'tt0113071']
# ['Mallrats', 'tt0113749']
# ['Nine Months', 'tt0113986']
# ['Boys on the Side', 'tt0112571']
# ['Circle of Friends', 'tt0112679']
# ['Exit to Eden', 'tt0109758']
# ['Fluke', 'tt0113089']
# ['Immortal Beloved', 'tt0110116']
# ['Tony Sirico', 'nm0802831']
# ['Nell', 'tt0110638']
# ['La Reine Margot', 'tt0110963']
# ['Corrina, Corrina', 'tt0109484']
# ['Dave Foley', 'nm0004929']
# ['Go Fish', 'tt10920376']
# ['Made in America', 'tt0107478']
# ["It's Always Sunny in Philadelphia", 'tt0472954']
# ['Shadowlands', 'tt0108101']
# ['Sirens', 'tt0111201']
# ['Threesome', 'tt0111418']
# ['Pretty Woman', 'tt0100405']
# ['Jane Eyre', 'tt1229822']
# ['The Last Supper', 'tt0113613']
# ['Ransom', 'tt0117438']
# ['The Crow: City of Angels', 'tt0115986']
# ['Michael Collins', 'tt0117039']
# ['The Ruling Class', 'tt0069198']
# ['Real Genius', 'tt0089886']
# ['Ben Gazzara', 'nm0001262']
# ['The Saint', 'tt2569088']
# ['The MatchMaker', 'tt0119632']
# ['Amistad', 'tt0118607']
# ['Tomorrow Never Dies', 'tt0120347']
# ['The Replacement Killers', 'tt0120008']
# ['Utomlennye solntsem', 'tt0111579']
# ['Red Corner', 'tt0119994']
# ['Jumanji: Welcome to the Jungle', 'tt2283362']
# ['Father of the Bride Part II', 'tt0113041']
# ['Across the Sea of Time', 'tt0112286']
# ['Lawnmower Man 2: Beyond Cyberspace', 'tt0116839']
# ['Fair Game', 'tt0977855']
# ['Screamers', 'tt0114367']
# ['Nick of Time', 'tt0113972']
# ['Beautiful Girls', 'tt0115639']
# ['Happy Gilmore', 'tt0116483']
# ['If Lucy Fell', 'tt0116606']
# ['Boomerang', 'tt0103859']
# ['Man of the Year', 'tt0483726']
# ['Addiction, The Consequences... And The Chaos', 'tt5549898']
# ['Casper Van Dien', 'nm0000680']
# ['Congo', 'tt0112715']
# ['Devil in a Blue Dress', 'tt0112857']
# ['Johnny Mnemonic', 'tt0113481']
# ['Kids', 'tt0113540']
# ['Mute Witness', 'tt0110604']
# ['Prophecy', 'tt0079758']
# ['Something to Talk About', 'tt0114496']
# ['Three Wishes', 'tt0114663']
# ['Castle Freak', 'tt0112643']
# ['Don Juan DeMarco', 'tt0112883']
# ['Drop Zone', 'tt0109676']
# ['Metumtemet', 'tt6575296']
# ['French Kiss', 'tt0113117']
# ['Little Odessa', 'tt0110365']
# ['Milk Money', 'tt0110516']
# ['Beyond Bedlam', 'tt0106402']
# ['Only You', 'tt7531138']
# ['The Perez Family', 'tt0114113']
# ['Raising the Wind', 'tt0055354']
# ['Gramps', 'tt0113206']
# ['Swimming with Sharks', 'tt0114594']
# ['Tommy Boy', 'tt0114694']
# ['The Baby-Sitters Club', 'tt0112435']
# ['Bullets Over Broadway', 'tt0109348']
# ['Crooklyn', 'tt0109504']
# ['It Could Happen to You', 'tt0110167']
# ['Ri¢hie Ri¢h', 'tt0110989']
# ['Speechless', 'tt5592146']
# ['Timecop', 'tt0111438']
# ['The Last House on the Left', 'tt0068833']
# ['Boys Life', 'tt0779794']
# ['In the Mouth of Madness', 'tt0113409']
# ['The Air Up There', 'tt0109067']
# ['Stratton', 'tt3567666']
# ["V.C. Andrews' Heaven", 'tt5834576']
# ['Jimmy Hollywood', 'tt0110197']
# ['Manhattan Murder Mystery', 'tt0107507']
# ['Menace II Society', 'tt0107554']
# ['Poetic Justice', 'tt0107840']
# ['The Program', 'tt3083008']
# ['Rising Sun', 'tt0107969']
# ['Ying', 'tt6864046']
# ['Thirty Two Short Films About Glenn Gould', 'tt0108328']
# ['Andre', 'tt0109120']
# ['The Celluloid Closet', 'tt0112651']
# ['A Great Day in Harlem', 'tt0109934']
# ['One Fine Day', 'tt0117247']
# ['Candyman: Farewell to the Flesh', 'tt0112625']
# ['Frisk', 'tt0113122']
# ['Girl 6', 'tt0116414']
# ['Edward Furlong', 'nm0000411']
# ['Space Jam', 'tt0117705']
# ['Mrs. Winterbourne', 'tt0117104']
# ['Faces', 'tt0062952']
# ['Mulholland Falls', 'tt0117107']
# ['The Great White Hype', 'tt0116448']
# ['Arrival', 'tt2543164']
# ['Phantom Thread', 'tt5776858']
# ['Daylight', 'tt0116040']
# ['North to Alaska', 'tt0054127']
# ['Fled', 'tt0116320']
# ['Power 98', 'tt0114170']
# ['Escape from L.A.', 'tt0116225']
# ['Bogus', 'tt0115725']
# ['Bulletproof', 'tt0115783']
# ['Halloween: The Curse of Michael Myers', 'tt0113253']
# ['The Gay Divorcee', 'tt0025164']
# ['Ninotchka', 'tt0031725']
# ['Meet John Doe', 'tt0033891']
# ['Huang jia shi jie', 'tt0093229']
# ['The Loch', 'tt6734482']
# ['Last Man Standing', 'tt1828327']
# ['The Glimmer Man', 'tt0116421']
# ['Pollyanna', 'tt0054195']
# ['The Shaggy Dog', 'tt0053271']
# ['Freeway', 'tt0116361']
# ['That Thing You Do!', 'tt0117887']
# ['To Gillian on Her 37th Birthday', 'tt0117924']
# ['Looking for Richard', 'tt0116913']
# ['Murder, My Sweet', 'tt0037101']
# ['Days of Thunder', 'tt0099371']
# ['The Perfect Candidate', 'tt6971114']
# ["2 ou 3 choses que je sais d'elle", 'tt0060304']
# ['The Bloody Child', 'tt0115715']
# ['Braindead', 'tt0103873']
# ['Bad Taste', 'tt0092610']
# ['Burlesque', 'tt1126591']
# ['Night on Earth', 'tt0102536']
# ['Paris Was a Woman', 'tt0114093']
# ['Amityville: Dollhouse', 'tt0115535']
# ["April Fool's Day", 'tt0090655']
# ['The Believers', 'tt0092632']
# ['Nosferatu a Venezia', 'tt0091651']
# ['Jingle All the Way', 'tt0116705']
# ['Il giardino dei Finzi Contini', 'tt0065777']
# ['My Fellow Americans', 'tt0117119']
# ['The Ice Storm', 'tt0119349']
# ['Sylvester Stallone', 'nm0000230']
# ['The Whole Wide World', 'tt0118163']
# ['Hearts and Minds', 'tt0071604']
# ['Fools Rush In', 'tt0119141']
# ['Mike Connors', 'nm0175528']
# ['Vegas Vacation', 'tt0120434']
# ['Love Jones', 'tt0119572']
# ['Picture Perfect', 'tt0119896']
# ['Career Girls', 'tt0118818']
# ["She's So Lovely", 'tt0120112']
# ['Money Talks', 'tt0119695']
# ['Excess Baggage', 'tt0119086']
# ['That Darn Cat!', 'tt0059793']
# ['The Peacemaker', 'tt0119874']
# ['Soul Food', 'tt0120169']
# ['Money Talks', 'tt0119695']
# ['Washington Square', 'tt0120481']
# ['Telling Lies in America', 'tt0120303']
# ['Year of the Horse', 'tt0120539']
# ['Phantoms', 'tt0119891']
# ['A Life Less Ordinary', 'tt0119535']
# ["Eve's Bayou", 'tt0119080']
# ['One Night Stand', 'tt5358948']
# ['The Tango Lesson', 'tt0120275']
# ['Mortal Kombat: Annihilation', 'tt0119707']
# ['Bent', 'tt2237324']
# ['Flubber', 'tt0119137']
# ['For Richer or Poorer', 'tt0119142']
# ['Home Alone 3', 'tt0119303']
# ['Scream 2', 'tt0120082']
# ['The Sweet Hereafter', 'tt0120255']
# ['Time Tracers', 'tt0128755']
# ['The Postman', 'tt0119925']
# ['The Winter Guest', 'tt0120521']
# ['Kundun', 'tt0119485']
# ['Mr. Magoo', 'tt0119718']
# ['The Big Lebowski', 'tt0118715']
# ['Afterglow', 'tt0118566']
# ['Ma vie en rose', 'tt0119590']
# ['Great Expectations', 'tt0119223']
# ['Oscar', 'tt0102603']
# ['Vermin', 'tt8292872']
# ['Half Baked', 'tt0120693']
# ['Miss Congeniality', 'tt0212346']
# ['Nil by Mouth', 'tt0119792']
# ['Twilight', 'tt1099212']
# ['U.S. Marshals', 'tt0120873']
# ['Love and Death on Long Island', 'tt0119574']
# ['Wild Things', 'tt0120890']
# ['Primary Colors', 'tt0119942']
# ['Lost in Space', 'tt5232792']
# ['Mercury Rising', 'tt0120749']
# ['City of Angels', 'tt0120632']
# ['La cité des enfants perdus', 'tt0112682']
# ['Two Bits', 'tt0114753']
# ['Ba wang bie ji', 'tt0106332']
# ['Dead Man', 'tt0112817']
# ['Da hong deng long gao gao gua', 'tt0101640']
# ['White Squall', 'tt0118158']
# ['Unforgettable', 'tt3462710']
# ['Down Periscope', 'tt0116130']
# ['La flor de mi secreto', 'tt0113083']
# ['The Craft', 'tt0115963']
# ['Harriet the Spy', 'tt0116493']
# ['The China Syndrome', 'tt0078966']
# ['The Island of Dr. Moreau', 'tt0116654']
# ['First Kid', 'tt0116311']
# ['The Funeral', 'tt0116378']
# ["The Preacher's Wife", 'tt0117372']
# ['Paradise Road', 'tt0119859']
# ['Brassed Off', 'tt0115744']
# ['A Thousand Acres', 'tt0120323']
# ['A Smile Like Yours', 'tt0120151']
# ['Murder in the First', 'tt2402061']
# ['Airheads', 'tt0109068']
# ['With Honors', 'tt0111732']
# ["What's Love Got to Do with It", 'tt0108551']
# ['Killing Zoe', 'tt0110265']
# ['Renaissance Man', 'tt0110971']
# ['Charade', 'tt0056923']
# ['The Fox and the Hound', 'tt0082406']
# ['Le grand bleu', 'tt0095250']
# ['Booty Call', 'tt0118750']
# ['How to Make an American Quilt', 'tt0113347']
# ['5 Days of War', 'tt1486193']
# ['The Indian in the Cupboard', 'tt0113419']
# ['Blue in the Face', 'tt0112541']
# ['Unstrung Heroes', 'tt0114798']
# ['Unzipped', 'tt0114805']
# ['Before Sunrise', 'tt0112471']
# ["Nobody's Fool", 'tt8097306']
# ['Tui shou', 'tt0105652']
# Sorry an error accured cant get data extracted
#
# error forTo Live (Huozhe) (1994)
# ['Dazed and Confused', 'tt0106677']
# ['Naked', 'tt0107653']
# ['Orlando', 'tt0107756']
# ['Ruby in Paradise', 'tt0108000']
# ['Some Folks Call It a Sling Blade', 'tt0108181']
# ['A Month by the Lake', 'tt0113849']
# ['Funny Face', 'tt0050419']
# ['An Affair to Remember', 'tt0050105']
# ['Little Lord Fauntleroy', 'tt0081062']
# ['The Inspector General', 'tt0041509']
# ['Winnie the Pooh and the Blustery Day', 'tt0063819']
# ['Boychoir', 'tt3302706']
# ['Mediterraneo', 'tt0102426']
# ['Passion Fish', 'tt0105107']
# ['Jerry Garcia', 'nm0305263']
# ['The Poison Rose', 'tt5862166']
# ['Fear', 'tt0116287']
# ['Solo: A Star Wars Story', 'tt3778644']
# ['The Substitute', 'tt0117774']
# ["Heaven's Prisoners", 'tt0116508']
# ['The Trigger Effect', 'tt0117965']
# ['Mother Night', 'tt0117093']
# ['Dangerous Ground', 'tt0118927']
# ['Maximum Risk', 'tt0117011']
# ["The Rich Man's Wife", 'tt0117473']
# ['Shadow Conspiracy', 'tt0120107']
# ['Blood', 'tt8991526']
# ['Turbulence', 'tt0120390']
# ['Underworld', 'tt0320691']
# ['The Beautician and the Beast', 'tt0118691']
# ["Cats Don't Dance", 'tt0118829']
# ['Anna Karenina', 'tt1781769']
# ['Keys to Tulsa', 'tt0116762']
# ['Head Above Water', 'tt0116502']
# ['Hercules', 'tt0119282']
# ['The Last Time I Committed Suicide', 'tt0119502']
# ['Some of My Best Friends', 'tt0259144']
# ['The Big Green', 'tt0112499']
# ['Stuart Saves His Family', 'tt0114571']
# ['Cabin Boy', 'tt0109361']
# ['Clean Slate', 'tt0109443']
# ['Lightning Jack', 'tt0110353']
# ['The Stupids', 'tt0117768']
# ['The Pest', 'tt0119887']
# ['That Darn Cat!', 'tt0059793']
# ['Geronimo: An American Legend', 'tt0107004']
# ['La double vie de Véronique', 'tt0101765']
# ['Bis ans Ende der Welt', 'tt0101458']
# ['Waiting for Guffman', 'tt0118111']
# ['I Shot Andy Warhol', 'tt0116594']
# ['Stealing Beauty', 'tt0117737']
# ['Basquiat', 'tt0115632']
# ['2 Days in the Valley', 'tt0115438']
# ['Private Parts', 'tt0119951']
# ['Anaconda', 'tt0118615']
# ["Romy and Michele's High School Reunion", 'tt0120032']
# ['Shiloh', 'tt0120118']
# ['Con Air', 'tt0118880']
# ['Trees Lounge', 'tt0117958']
# ['¡Átame!', 'tt0101026']
# ['Dip huet seung hung', 'tt0097202']
# ['Gaslight', 'tt0036855']
# ['8½', 'tt0056801']
# ['Fast, Cheap & Out of Control', 'tt0119107']
# ["Fathers' Day", 'tt0119109']
# ['Mrs Dalloway', 'tt0119723']
# ['Fire Down Below', 'tt0119123']
# ['The Lay of the Land', 'tt0123953']
# ['Shooter', 'tt4181172']
# ['Grumpier Old Men', 'tt0113228']
# ['Jury Duty', 'tt0113500']
# ['The Beverly Hillbillies', 'tt0055662']
# ['Lassie', 'tt0046617']
# ['Little Big League', 'tt0110363']
# ['Homeward Bound II: Lost in San Francisco', 'tt0116552']
# ['Galaxy Quest', 'tt0177789']
# ['Cool Runnings', 'tt0106611']
# ['Drop Dead Fred', 'tt0101775']
# ['Grease 2', 'tt0084021']
# ['Switchback', 'tt0119210']
# ['Hamlet', 'tt0116477']
# ['Two If by Sea', 'tt0118002']
# ['Forget Paris', 'tt0113097']
# ['Just Cause', 'tt0113501']
# ['Rent-a-Kid', 'tt0114268']
# ['Paper Towns', 'tt3622592']
# ['Fearless', 'tt5973164']
# ['Malice', 'tt0107497']
# ['Multiplicity', 'tt0117108']
# ["She's the One", 'tt0117628']
# ['House Arrest', 'tt11163028']
# ['The Ghost and Mrs. Muir', 'tt0039420']
# ['The Associate', 'tt0115580']
# ['Dracula: Dead and Loving It', 'tt0112896']
# ['Now and Then', 'tt0114011']
# ['Mr. Wrong', 'tt0117102']
# ['A Simple Twist of Fate', 'tt0111194']
# ['Cronos', 'tt0104029']
# ['The Pallbearer', 'tt0117283']
# ['War, the Inside Story: Mission Berlin', 'tt5610880']
# ["Don't Be a Menace to South Central While Drinking Your Juice in the Hood", 'tt0116126']
# ['The Adventures of Pinocchio', 'tt0115472']
# ['The Evening Star', 'tt0116240']
# ['O Que é Isso, Companheiro?', 'tt0119815']
# ['A Little Princess', 'tt0113670']
# ['Freelancers', 'tt1815708']
# ['Koyaanisqatsi', 'tt0085809']
# ['Balto', 'tt0112453']
# ['Bottle Rocket', 'tt0115734']
# Sorry an error accured cant get data extracted
#
# error forStar Maker, The (Uomo delle stelle, L') (1995)
# ['Amateur', 'tt5580392']
# ['Living in Oblivion', 'tt0113677']
# ['Tart', 'tt0203975']
# ["A Pyromaniac's Love Story", 'tt0114210']
# ['Shallow Grave', 'tt0111149']
# ['Reality Bites', 'tt0110950']
# ['A Man of No Importance', 'tt0110455']
# ['The Pagemaster', 'tt0110763']
# ['Love and a .45', 'tt0110395']
# ['Oliver!', 'tt0063385']
# ["Joe's Apartment", 'tt0116707']
# ['Mécaniques célestes', 'tt0107537']
# ['Curdled', 'tt0115994']
# ['Female Perversions', 'tt0116293']
# ['Albino Alligator', 'tt0115495']
# ['Anne Frank Remembered', 'tt0112373']
# ['Carried Away', 'tt0115837']
# ["It's My Party", 'tt0113443']
# ['Bloodsport 2', 'tt0112536']
# ['Double Team', 'tt0119013']
# ['Speed 2: Cruise Control', 'tt0120179']
# ['Sliver', 'tt0108162']
# ["Pete's Dragon", 'tt0076538']
# ['Dear God', 'tt0116059']
# ['Live Nude Girls', 'tt0113674']
# ['A Thin Line Between Love and Hate', 'tt0117891']
# ['High School High', 'tt0116531']
# ['Commandments', 'tt0115927']
# ['Kate Haines', 'nm8125449']
# ['Flirting with Disaster', 'tt0116324']
# ['Pao Da Shuang Deng', 'tt0110769']
# ['What Happened Was...', 'tt0111689']
# ['Six Degrees of Separation', 'tt0108149']
# ['Two Much', 'tt0118001']
# ['Trust', 'tt5664952']
# ["C'est arrivé près de chez vous", 'tt0103905']
# ['Firestorm', 'tt0120670']
# ['The Newton Boys', 'tt0120769']
# ['Beyond Rangoon', 'tt0112495']
# ['Feast of July', 'tt0113044']
# ['Death and the Maiden', 'tt0109579']
# ['Tank Girl', 'tt0114614']
# ['Double Happiness', 'tt0109655']
# ['Cobb', 'tt0109450']
# ['Mrs. Parker and the Vicious Circle', 'tt0110588']
# ['Faithful', 'tt0116269']
# ['Twelfth Night or What You Will', 'tt0117991']
# ['The Mark of Zorro', 'tt0032762']
# ['Surviving Picasso', 'tt0117791']
# ['Up in Smoke', 'tt0078446']
# ['Some Kind of Wonderful', 'tt0094006']
# ["I'm Not Rappaport", 'tt0116601']
# ['Les parapluies de Cherbourg', 'tt0058450']
# ['They Made Me a Criminal', 'tt0032022']
# ['The Last Time I Saw Paris', 'tt0047162']
# ['A Farewell to Arms', 'tt0022879']
# ['The Innocents', 'tt8021824']
# ['The Old Man and the Sea', 'tt0052027']
# ['The Truman Show', 'tt0120382']
# ['Heidi Fleiss: Hollywood Madam', 'tt0113283']
# ['Chung Hing sam lam', 'tt0109424']
# ["Jupiter's Wife", 'tt0110217']
# ['Safe', 'tt7902072']
# ['Feeling Minnesota', 'tt0116289']
# ['Escape to Witch Mountain', 'tt0072951']
# ['Get on the Bus', 'tt0116404']
# ['The Doors', 'tt0101761']
# ['Ghosts of Mississippi', 'tt0116410']
# ['Beautiful Thing', 'tt0115640']
# ['Best Men', 'tt0118702']
# ['Hackers', 'tt0113243']
# ['The Road to Wellville', 'tt0111001']
# ['War Room', 'tt3832914']
# ['When We Were Kings', 'tt0118147']
# ['Sydney', 'tt0119256']
# ['The Quiet Room', 'tt7193218']
# ['Blue Chips', 'tt0109305']
# ['Calendar Girl', 'tt0106505']
# ['My Family', 'tt0257315']
# ['Thomasin McKenzie', 'nm5057169']
# ['Walkabout', 'tt0067959']
# ['Last Dance', 'tt0116827']
# ['Original Gangstas', 'tt0117260']
# ['In Love and War', 'tt0116621']
# ['Backbeat', 'tt0106339']
# ['Alphaville, une étrange aventure de Lemmy Caution', 'tt0058898']
# ['Les rendez-vous de Paris', 'tt0114266']
# ['Xích lô', 'tt0112767']
# ['The Relic', 'tt0120004']
# ['La fille seule', 'tt0113057']
# ['Greta', 'tt2639336']
# ['Love! Valour! Compassion!', 'tt0119578']
# ['Palookaville', 'tt0117284']
# ['Phat Beach', 'tt0117332']
# ['Portrait de la jeune fille en feu', 'tt8613070']
# ['Zeus and Roxanne', 'tt0120550']
# ['Big Bully', 'tt0115676']
# ['Love', 'tt3774694']
# ['The Sum of Us', 'tt0111309']
# ['Little Buddha', 'tt0107426']
# ['Fresh', 'tt0109842']
# ['Spanking the Monkey', 'tt0111252']
# ['Les roseaux sauvages', 'tt0111019']
# ['Women, the Internet and Election 2000', 'tt1137788']
# ['Bliss', 'tt9026524']
# ['Caught', 'tt5596468']
# ['Hugo Pool', 'tt0119327']
# ['Welcome to Sarajevo', 'tt0120490']
# ['Dunston Checks In', 'tt0116151']
# ['Major Payne', 'tt0110443']
# ['Man of the House', 'tt0331933']
# ['I Love Trouble', 'tt0110093']
# ['A Low Down Dirty Shame', 'tt0110399']
# ['Cops and Robbersons', 'tt0109480']
# ['The Cowboy Way', 'tt0109493']
# ['The Endless Summer 2', 'tt0109729']
# ['In the Army Now', 'tt0110123']
# ['The Inkwell', 'tt0110137']
# ['The Jezebels', 'tt0073778']
# ['Young Guns II', 'tt0100994']
# ['Prefontaine', 'tt0119937']
# ['That Old Feeling', 'tt0120318']
# ['A Letter from Death Row', 'tt0119521']
# ['The Boys of St. Vincent', 'tt0106473']
# ['Pred dozhdot', 'tt0110882']
# ['Once Were Warriors', 'tt0110729']
# ['Bad Company/Far from Home: The Adventures of Yellow Dog/Murder in the First/Higher Learning/S.F.W./Strawberry and Chocolate', 'tt6145568']
# ['Les nuits fauves', 'tt0105032']
# ['A Family Thing', 'tt0116275']
# ['Plein soleil', 'tt0054189']
# ["We Visit the 'Cemetery Man' in: Dellamorte Dellamore", 'tt2332155']
# ['Kimberly Williams-Paisley', 'nm0931090']
# ['Marlene Dietrich: Shadow and Light', 'tt0116992']
# ['Der bewegte Mann', 'tt0109255']
# ['Top Hat', 'tt0027125']
# ['To Be or Not to Be', 'tt0035446']
# ['Danger Man', 'tt0058846']
# ['Amos', 'tt0088713']
# ['Jade', 'tt0113451']
# ['Kiss of Death', 'tt0039536']
# ['Mixed Nuts', 'tt0110538']
# ['Virtuosity', 'tt0114857']
# ['Blue Sky', 'tt0109306']
# ['Flesh and Bone', 'tt3507484']
# ['Guilty as Sin', 'tt0107057']
# ['Ai no korîda', 'tt0074102']
# ['Barb Wire', 'tt0115624']
# ['Kissed', 'tt0116783']
# ['Assassins', 'tt0112401']
# ['Friday', 'tt0113118']
# ['A Goofy Movie', 'tt0113198']
# ['Higher Learning', 'tt0113305']
# ['When a Man Loves a Woman', 'tt0111693']
# ['Judgment Night', 'tt0107286']
# ['King of the Hill', 'tt0118375']
# ['Scout Taylor-Compton', 'nm0174021']
# ['Angus', 'tt0112368']
# ['Night Falls on Manhattan', 'tt0119783']
# ['An Awfully Big Adventure', 'tt0112427']
# ['Under Siege 2: Dark Territory', 'tt0114781']
# ['Poison Ivy II', 'tt0114151']
# ['Prêt-à-Porter', 'tt0110907']
# ['Marked for Death', 'tt0100114']
# ['Madonna: Truth or Dare', 'tt0102370']
# ['Nénette et Boni', 'tt0117221']
# ['Frank Sinatra', 'nm0000069']
# ['The Big Bang Theory', 'tt0898266']
# ['Other Voices, Other Rooms', 'tt0119845']
# ['Twisted Pair', 'tt8196068']
# ['À fond', 'tt4993964']
# ['Cutthroat Island', 'tt0112760']
# ['Kôkaku Kidôtai', 'tt0113568']
# ['Servant', 'tt8068860']
# ['La vieille qui marchait dans la mer', 'tt0103207']
# ['Night Fliers', 'tt0480256']
# ['Metro', 'tt0119664']
# ["Gridlock'd", 'tt0119225']
# ['Bushwhacked', 'tt0112602']
# ['Bad Girls', 'tt0109198']
# ['Blink', 'tt0109297']
# ['The Revenger: An Unromantic Comedy', 'tt7051624']
# ['Best of the Best 3: No Turning Back', 'tt0112483']
# ['Shekvarebuli kulinaris ataserti retsepti', 'tt0117050']
# ['Le mépris', 'tt0057345']
# ['Hands that Bind', 'tt9014060']
# ["Gone Fishin'", 'tt0119214']
# ['Broken English', 'tt0772157']
# ['The Designated Mourner', 'tt0118964']
# ['The Designated Mourner', 'tt0118964']
# ['Trial & Error', 'tt5511512']
# ['Pie in the Sky', 'tt0106102']
# ['Total Eclipse', 'tt0114702']
# ['The Run of the Country', 'tt0114307']
# ['Walking and Talking', 'tt0118113']
# ['Foxfire', 'tt0116353']
# ['Nothing to Lose', 'tt0119807']
# ['Star Maps', 'tt0120197']
# ['Pane e cioccolata', 'tt0070506']
# ['Clockers', 'tt0112688']
# ['Bitter Moon', 'tt0104779']
# ['Love in the Afternoon', 'tt0050658']
# ['Life with Mikey', 'tt0107413']
# ['North', 'tt0110687']
# ['Talking About Sex', 'tt0111357']
# ['Color of Night', 'tt0109456']
# ['RoboCop 3', 'tt0107978']
# ['Una pallottola nel cuore', 'tt3175512']
# ['Sunset Park', 'tt0117784']
# ['Set It Off', 'tt0117603']
# ['Selena', 'tt0120094']
# ['Wild America', 'tt0120512']
# ['Gang Related', 'tt2719784']
# ['Edward G. Robinson', 'nm0000064']
# ['The Grass Harp', 'tt0113211']
# ['Out to Sea', 'tt0119848']
# ['Before and After', 'tt0115645']
# ['Princess Caraboo', 'tt0110892']
# ['Shall We Dance', 'tt0358135']
# ['Eddie Murphy', 'nm0000552']
# ['Denise Calls Up', 'tt0112844']
# ['Jack & Sarah', 'tt0113448']
# ['Country Life', 'tt0109491']
# ['Celtic Pride', 'tt0115851']
# ['A Simple Wish', 'tt0120133']
# ['Star Kid', 'tt0120478']
# ['Ayn Rand: A Sense of Life', 'tt0118662']
# ['Kicked in the Head', 'tt0119457']
# ['Indian Summer', 'tt0107212']
# ['Zandalee', 'tt0101004']
# ['The Band Wagon', 'tt0045537']
# ['Penny Serenade', 'tt0034012']
# ["'Til There Was You", 'tt0118523']
# ['Stripes', 'tt0083131']
# ['Late Bloomers', 'tt1572502']
# ['How to Get Away with Murder', 'tt3205802']
# ['New York Undercover Cop', 'tt0117169']
# ['Senior Trip', 'tt0113936']
# ['Delta of Venus', 'tt0109593']
# ['Carmen Miranda: Bananas Is My Business', 'tt0109381']
# ['Babyfever', 'tt0109191']
# ['A Very Natural Thing', 'tt0072362']
# ['A Walk in the Sun', 'tt0038235']
# ['Waiting to Exhale', 'tt0114885']
# ['The Pompatus of Love', 'tt0117357']
# ['Palmetto', 'tt0120782']
# ['Surviving the Game', 'tt0111323']
# ['Inventing the Abbotts', 'tt0119381']
# ['The Horse Whisperer', 'tt0119314']
# ['The Journey of August King', 'tt0113490']
# ['Catwalk', 'tt0103384']
# ['The Neon Bible', 'tt0113952']
# ['Homage', 'tt0113319']
# ['Open Season', 'tt0400717']
# ['Métisse', 'tt0107642']
# ['Wu Kui', 'tt0111752']
# ['Loaded', 'tt6210192']
# ['Augustine Frizzell', 'nm1435438']
# ['Jongens', 'tt3318220']
# ['The Captive', 'tt2326612']
# ['Of Love and Shadows', 'tt0110712']
# ['Lowlife', 'tt7012864']
# ['Un été inoubliable', 'tt0111546']
# ['The Last Klezmer: Leopold Kozlowski, His Life and Music', 'tt0113610']
# ["En compagnie d'Antonin Artaud", 'tt0106810']
# ['Sibak', 'tt0111180']
# ['Somebody to Love', 'tt0111237']
# ['American Buffalo', 'tt0115530']
# ['Kazaam', 'tt0116756']
# ['Larger Than Life', 'tt0116823']
# ['Two Deaths', 'tt0117999']
# ['Stefano Quantestorie', 'tt0108220']
# ['The Crude Oasis', 'tt0112746']
# ['Hedd Wyn', 'tt0104403']
# ['The Convenient Truth', 'tt9367692']
# ['Lotto Land', 'tt0113695']
# ['Xinghua san yue tian', 'tt0108227']
# Sorry an error accured cant get data extracted
#
# error forDay the Sun Turned Cold, The (Tianguo niezi) (1994)
# ['Dingo', 'tt0104109']
# ['Narayama bushikô', 'tt0084390']
# ['Every Other Weekend', 'tt6111598']
# ['Mille bolle blu', 'tt0107575']
# ['Wuya yu maque', 'tt0042054']
# ["Lover's Knot", 'tt0116934']
# ['Schatten der Engel', 'tt0075169']
# ['06', 'tt0109001']
# ['Venice/Venice', 'tt0105729']
# ['Infinity', 'tt0116635']
# ["Ed's Next Move", 'tt0116167']
# ['For the Moment', 'tt0109823']
# ['The Deadly Cure', 'tt0645145']
# ['7 Days in Venice Beach', 'tt5144366']
# ['La vie sexuelle des Belges 1950-1978', 'tt0111622']
# ['The Search for One-eye Jimmy', 'tt0117577']
# ['American Strays', 'tt0115531']
# ['The Leopard Son', 'tt0116859']
# ['Bird of Prey', 'tt7245458']
# ['Johnny 100 Pesos', 'tt0107274']
# ['JLG/JLG - autoportrait de décembre', 'tt0110173']
# ['Faust: Love of the Damned', 'tt0223268']
# ['Mina Tannenbaum', 'tt0110521']
# ['Il Cristo proibito', 'tt0042354']
# ["J'ai pas sommeil", 'tt0110171']
# ['Mean Machine', 'tt0291341']
# ['Stranger Things', 'tt4574334']
# ['Ohayô', 'tt0053134']
# ['Falling in Love Again', 'tt0080714']
# ['The Cement Garden', 'tt0106535']
# ['Meet Wally Sparks', 'tt0119644']
# ['Hotel de Love', 'tt0116565']
# ['Rhyme', 'nm8372974']
# ['Love and Other Catastrophes', 'tt0116931']
# ['Hollow Reed', 'tt0113314']
# ['Losing Chase', 'tt0116920']
# ['Le bonheur', 'tt0058985']
# ['The Second Jungle Book: Mowgli & Baloo', 'tt0120087']
# ['Squeeze', 'tt0117724']
# ["Roseanna's Grave", 'tt0120034']
# ['Tetsuo II: Body Hammer', 'tt0105569']
# ['Fall', 'tt0119098']
# ['Gabbeh', 'tt0116384']
# ['Mondo', 'tt0117076']
# ['The Innocent Sleep', 'tt0113425']
# ['For Ever Mozart', 'tt0116334']
# ['Locusts', 'tt7959296']
# ['Stag', 'tt4845906']
# ['Swept from the Sea', 'tt0120257']
# ['Hurricane', 'tt0119338']
# ['Stonewall', 'tt3018070']
# ['Of Human Bondage', 'tt0025586']
# ['Anna', 'tt7456310']
# ['Black Christmas', 'tt0071222']
# ['Picture Bride', 'tt0114129']
# ['M. Butterfly', 'tt0107468']
# ['Io speriamo che me la cavo', 'tt0107225']
# ['Caro diario', 'tt0109382']
# ['Withnail & I', 'tt0094336']
# ['Boys Life 2', 'tt0118762']
# ['When Night Is Falling', 'tt0114916']
# ['The Specialist', 'tt0111255']
# ['Gordon Willis', 'nm0932336']
# ['The Swan Princess', 'tt0111333']
# ['Sugar Hill', 'tt0107079']
# ['Barbarella', 'tt0062711']
# ['The Land Before Time III: The Time of the Great Giving', 'tt0113596']
# ['Street Fighter', 'tt0111301']
# ['Coldblooded', 'tt0112702']
# ['The Next Karate Kid', 'tt0110657']
# ['No Escape', 'tt1781922']
# ['The Turning', 'tt7510346']
# ['The Joy Luck Club', 'tt0107282']
# ['Highlander III: The Sorcerer', 'tt0110027']
# ["Gilligan's Island: The Untold Tales", 'tt0568382']
# ['Mi vida loca', 'tt0107566']
# ['Suture', 'tt0108260']
# ['The Walking Dead', 'tt1520211']
# ['I Like It Like That', 'tt0110091']
# ["I'll Do Anything", 'tt0110097']
# ['Grace of My Heart', 'tt0116442']
# ['Drunks', 'tt0112907']
# ['Suburbia', 'tt0086589']
# ['Sliding Doors', 'tt0120148']
# ['Ill Gotten Gains', 'tt0119352']
# ['Legal Deceit', 'tt0130073']
# ['Almighty Thor', 'tt1792794']
# ['Men of Means', 'tt0119655']
# ['Shooting Fish', 'tt0120122']
# ['Steal Big Steal Little', 'tt0114536']
# ['Mr. Jones', 'tt6828390']
# ['House Party 3', 'tt0110064']
# ['Panther', 'tt0114084']
# ["Jason's Lyric", 'tt0110186']
# ['Above the Rim', 'tt0109035']
# ['Moonlight and Valentino', 'tt0113851']
# ['The Scarlet Letter', 'tt0114345']
# ['8 Seconds', 'tt0109021']
# ['That Darn Cat!', 'tt0059793']
# ['Ladybird Ladybird', 'tt0110296']
# ['Bye Bye, Love', 'tt2639596']
# ['Century', 'tt0106537']
# ['Ma saison préférée', 'tt0107471']
# ['Pather Panchali', 'tt0048473']
# ['Golden Earrings', 'tt0039428']
# ['Foreign Correspondent', 'tt0032484']
# ['Lady of Burlesque', 'tt0036094']
# ['Angel on My Shoulder', 'tt0038300']
# ['Angel and the Badman', 'tt0039152']
# ['Outlaw King', 'tt6679794']
# ['Beat the Devil', 'tt0046414']
# ['Love Is All There Is', 'tt0116928']
# ['A Damsel in Distress', 'tt0028757']
# ['Madame Butterfly', 'tt0023169']
# ['Sleepover', 'tt0368975']
# ['Here Comes Cookie', 'tt0026465']
# ['Aladdin and the King of Thieves', 'tt0115491']
# ["This Boy's Life", 'tt0108330']
# ['The Stars Fell on Henrietta', 'tt0114534']
# ['Last Summer in the Hamptons', 'tt0113612']
# ["Margaret's Museum", 'tt0113774']
# ['The Saint of Fort Washington', 'tt0108026']
# ['A Cure for Wellness', 'tt4731136']
# ['Tom and Huck', 'tt0112302']
# ['Gumby 1', 'tt0113234']
# ['Hideaway', 'tt0113303']
# ['Les visiteurs', 'tt0108500']
# ['A Little Princess', 'tt0113670']
# ['Nina Takes a Lover', 'tt0110671']
# ['Bhaji on the Beach', 'tt0106408']
# ['Raw Deal', 'tt0091828']
# ['Nightwatch', 'tt0119791']
# ['Dead Presidents', 'tt0112819']
# ['Reckless', 'tt2726196']
# ['Herbie Rides Again', 'tt0071607']
# ['S.F.W.', 'tt0111048']
# ['The Gate of Heavenly Peace', 'tt0113147']
# ['The Man in the Iron Mask', 'tt0120744']
# ['The Jerky Boys', 'tt0110189']
# ['Le colonel Chabert', 'tt0109454']
# ['Girl in the Cadillac', 'tt0113173']
# ['Even Cowgirls Get the Blues', 'tt0106834']
# ['Germinal', 'tt0107002']
# ['Chasers', 'tt0109403']
# ['Faust: Love of the Damned', 'tt0223268']
# ['Tough and Deadly', 'tt0114706']
# ['Okno v Parizh', 'tt0110719']
# ['A Modern Affair', 'tt0113839']
# ['Il mostro', 'tt0076411']
# ['Holiday', 'tt0030241']
# ['Carpool', 'tt0115836']
# ['Al Hirschfeld: The Line King', 'tt2147657']
# ['Jeremy Roloff', 'nm2203837']
# ['Grosse fatigue', 'tt0109942']
# ['Santa with Muscles', 'tt0117550']
# Sorry an error accured cant get data extracted
#
# error forPrisoner of the Mountains (Kavkazsky Plennik) (1996)
# ['Naked in New York', 'tt0110623']
# ['Gold Diggers: The Secret of Bear Mountain', 'tt0113188']
# ['Der bewegte Mann', 'tt0109255']
# ['Killer: A Journal of Murder', 'tt0113542']
# ['Fenella Woolgar', 'nm0941211']
# ['Trois vies et une seule mort', 'tt0117968']
# ['The Babysitter', 'tt4225622']
# ['Getting Even with Dad', 'tt0109891']
# ['Mad Dog Time', 'tt0116953']
# ['Children of the Revolution', 'tt0115886']
# ['Apur Sansar', 'tt0052572']
# ['Sprung', 'tt0120190']
# ['Dream with the Fishes', 'tt0119019']
# ['Wings of Courage', 'tt0114952']
# ['Wedding Gift', 'tt0893566']
# ['Race the Sun', 'tt0117427']
# ['Losing Isaiah', 'tt0113691']
# ['New Jersey Drive', 'tt0113967']
# ['Fear', 'tt0116287']
# ['Mr. Wonderful', 'tt0107613']
# ['Trial by Jury', 'tt0111488']
# ['A Good Man in Africa', 'tt0109920']
# ['Jeder für sich und Gott gegen alle', 'tt0071691']
# ['The Object of My Affection', 'tt0120772']
# ['Witness', 'tt0090329']
# ['Senseless', 'tt0120820']
# ['Nowhere', 'tt0119809']
# ['Underground', 'tt0114787']
# ['Jefferson in Paris', 'tt0113463']
# ['Far from Home: The Adventures of Yellow Dog', 'tt0113028']
# ['Foreign Student', 'tt0109828']
# ['De eso no se habla', 'tt0106678']
# ['Twin Town', 'tt0120394']
# ["L'enfer", 'tt0109731']
# ['Lai Qing Wang', 'nm2018839']
# ['Cosi', 'tt0115951']
# ['All Over Me', 'tt0118586']
# ['Being Human', 'tt1349938']
# ['The Amazing Panda Adventure', 'tt0112342']
# ['The Beans of Egypt, Maine', 'tt0109226']
# ['The Scarlet Letter', 'tt0114345']
# ['Johns', 'tt0116714']
# ['It Takes Two', 'tt0113442']
# ['Frankie Starlight', 'tt0113107']
# ['Shadows of Conscience', 'tt0012670']
# ['The Morning Show', 'tt7203552']
# ['Avlu', 'tt7923832']
# ['Dream Man', 'tt0112899']
# ['Destiny Turns on the Radio', 'tt0112854']
# ['The Glass Shield', 'tt0109906']
# ['Lincoln Rhyme: Hunt for the Bone Collector', 'tt9307990']
# ['Underneath', 'tt0114788']
# ['Safe Passage', 'tt0111054']
# ['The Secret Adventures of Tom Thumb', 'tt0108069']
# ["By Dawn's Early Light", 'tt0099197']
# ['Yankee Zulu', 'tt0111787']
# ['Aparajito', 'tt0048956']
# ['Hostile Intentions', 'tt0110061']
# ['Coup de torchon', 'tt0082206']
# ['Tigrero: A Film That Was Never Made', 'tt0111430']
# Sorry an error accured cant get data extracted
#
# error forEye of Vichy, The (Oeil de Vichy, L') (1993)
# ['Das Versprechen', 'tt4552298']
# ['To Cross the Rubicon', 'tt0103095']
# ['Daens', 'tt0104046']
# ['The Man from Down Under', 'tt0031612']
# ['Careful', 'tt0103926']
# ['Vermont Is for Lovers', 'tt0105737']
# Sorry an error accured cant get data extracted
#
# error forVie est belle, La (Life is Rosey) (1987)
# ['Quartier Mozart', 'tt0105201']
# ['Touki-Bouki', 'tt0070820']
# ['Wend Kuuni', 'tt0084898']
# ['Histoires extraordinaires', 'tt0063715']
# ["Pharaoh's Army", 'tt0114122']
# ['Yo, la peor de todas', 'tt0100990']
# ['Hol volt, hol nem volt', 'tt0093199']
# ['La mort en ce jardin', 'tt0049521']
# ['La collectionneuse', 'tt0061495']
# ['Baton Rouge', 'tt0094822']
# ['Christine', 'tt0051477']
# ['The Woman in Question', 'tt1098459']
# ['T-Men', 'tt0039881']
# ['The Invitation', 'tt2400463']
# ['Symphonie Pastorale', 'tt3697948']
# ['Obsession', 'tt6023242']
# ['Lv Xiucai wu shou shi xue tu, Bai Zhantang lin zhong tu xin sheng', 'tt9795168']
# ['Terror in a Texas Town', 'tt0052287']
# ['Salut cousin!', 'tt0117544']
# ['Schizopolis', 'tt0117561']
# ['En avoir (ou pas)', 'tt0112951']
# ['Do lok tin si', 'tt0112913']
# ['Magic Hour', 'tt2302701']
# ['Death in Brunswick', 'tt0101692']
# ['Abominable', 'tt6324278']
# ['Chopping Mall', 'tt0090837']
# ['Nemesis 2: Nebula', 'tt0113948']
# ['Romper Stomper', 'tt0105275']
# ['City of Industry', 'tt0118859']
# ["Someone Else's America", 'tt0114494']
# ['Guantanamera', 'tt0109949']
# ['Office Killer', 'tt0119819']
# ['A Price Above Rubies', 'tt0120793']
# ['Angel-A', 'tt0473753']
# ['He Walked by Night', 'tt0040427']
# ['Love Serenade', 'tt0116930']
# ['Deceiver', 'tt0119527']
# ['Hurricane', 'tt0119338']
# ['Patrick Swayze', 'nm0000664']
# ['B*A*P*S', 'tt0118663']
# ['Truth or Consequences, N.M.', 'tt0120383']
# ['Intimate Relations', 'tt0116643']
# ['The Leading Man', 'tt0116845']
# ['Tokyo Fist', 'tt0114690']
# ['The Reluctant Debutante', 'tt0052126']
# ['Warriors of Virtue', 'tt0120479']
# ['Desert Winds', 'tt0112849']
# ['Hugo Pool', 'tt0119327']
# ['King of New York', 'tt0099939']
# ['Lust och fägring stor', 'tt0113720']
# ['The Sixth Man', 'tt0120142']
# ['Butterfly Kiss', 'tt0112604']
# ['Paris, France', 'tt0107779']
# ['La cérémonie', 'tt0112769']
# ['Hush', 'tt5022702']
# ['Nightwatch', 'tt0119791']
# ['Keiner liebt mich', 'tt0110251']
# ['The Good Wife', 'tt1442462']
# ['Lamerica', 'tt0110299']
# ['Nico Icon', 'tt0113973']
# Sorry an error accured cant get data extracted
#
# error forSilence of the Palace, The (Saimt el Qusur) (1994)
# ['Slingshot', 'tt0410626']
# ['Land and Freedom', 'tt0114671']
# ['Á köldum klaka', 'tt0109028']
# Sorry an error accured cant get data extracted
#
# error forEtz Hadomim Tafus (Under the Domin Tree) (1994)
# ['Les deux amis', 'tt4176556']
# ['Brothers in Trouble', 'tt0112586']
# ['Girls Town', 'tt0052850']
# ['Normal Life', 'tt0117202']
# Sorry an error accured cant get data extracted
#
# error forBitter Sugar (Azucar Amargo) (1996)
# ['Le huitième jour', 'tt0116581']
# ['Dadetown', 'tt0112777']
# ["Some Mother's Son", 'tt0117690']
# ['Angel Baby', 'tt0054628']
# ['Sudden Manhattan', 'tt0117775']
# ['The Butcher Boy', 'tt0118804']
# ['Men with Guns', 'tt0119657']
# ['Hana-bi', 'tt0119250']
# ['Niagara, Niagara', 'tt0119780']
# ['The Big Red One', 'tt0080437']
# ['The Butcher Boy', 'tt0118804']
# ['The Spanish Prisoner', 'tt0120176']
# ['Feng yue', 'tt0116295']
# ['Entertaining Angels: The Dorothy Day Story', 'tt0116212']
# ['Frank Sinatra', 'nm0000069']
# ['A Simple Favor', 'tt7040874']
# ['Little City', 'tt0119548']
# ['This Means War', 'tt1596350']
# ['The Substance of Fire', 'tt0117773']
# ['Der Richter und sein Henker', 'tt0075140']
# ['Small Faces', 'tt0114474']
# ['Naui Nara', 'tt10850888']
# ['Rough Magic', 'tt0114303']
# ['Nothing Personal', 'tt1320352']
# ['8 Heads in a Duffel Bag', 'tt0118541']
# ["A Brother's Kiss", 'tt0118783']
# ['Ripe', 'tt0117482']
# ['The Next Step', 'tt2374744']
# ['Wedding Bell Blues', 'tt0118127']
# ['MURDER and murder', 'tt0116949']
# ['Tainted', 'tt3952864']
# ['A Further Gesture', 'tt0116379']
# ['Kika', 'tt0107315']
# ['Durante la tormenta', 'tt6908274']
# ['Mamma Roma', 'tt0056215']
# ['The Sunchaser', 'tt0117781']
# ['The War at Home', 'tt0460692']
# ['Another Chance', 'tt0096824']
# ['Matisyahu', 'nm1875458']
# ['B. Monkey', 'tt0120594']
# ['Sliding Doors', 'tt0120148']
# ['USO Crazy', 'tt3741044']
# ['Cerro Torre: Schrei aus Stein', 'tt0102855']

# %%
movies.head()
# Out:
#    movie_id              title release_date  video_release_date  \
# 0         1   Toy Story (1995)  01-Jan-1995                 NaN
# 1         2   GoldenEye (1995)  01-Jan-1995                 NaN
# 2         3  Four Rooms (1995)  01-Jan-1995                 NaN
# 3         4  Get Shorty (1995)  01-Jan-1995                 NaN
# 4         5     Copycat (1995)  01-Jan-1995                 NaN
#
#                                             imdb_url imdbID imdbName
# 0  http://us.imdb.com/M/title-exact?Toy%20Story%2...    N/A      N/A
# 1  http://us.imdb.com/M/title-exact?GoldenEye%20(...    N/A      N/A
# 2  http://us.imdb.com/M/title-exact?Four%20Rooms%...    N/A      N/A
# 3  http://us.imdb.com/M/title-exact?Get%20Shorty%...    N/A      N/A
# 4  http://us.imdb.com/M/title-exact?Copycat%20(1995)    N/A      N/A

# %%
#test OMDBAPI
movieName = 'Shanghai Triad'
imdbID = 'tt0047437'
API_KEY = 'acaee3e0'
url2 = "http://www.omdbapi.com/?i="+imdbID+"&plot=full&apikey="+API_KEY
r = requests.get(url2)

print(jsonA)
jsonA = r.json()

if (jsonA['Response']=='False'):
    print("movieName  ERRORRR")
else:
        print (jsonA['Title'])
        a = pd.DataFrame(jsonA)

###1000 request per day, unless pay then 100k
# Out:
# {'Title': 'Sabrina', 'Year': '1954', 'Rated': 'Passed', 'Released': '15 Oct 1954', 'Runtime': '113 min', 'Genre': 'Comedy, Drama, Romance', 'Director': 'Billy Wilder', 'Writer': 'Billy Wilder, Samuel A. Taylor, Ernest Lehman', 'Actors': 'Humphrey Bogart, Audrey Hepburn, William Holden', 'Plot': "Linus and David Larrabee are the two sons of a very wealthy family. Linus is all work -- busily running the family corporate empire with no time for a wife and family. David is all play -- technically employed in the family business but never showing up for work, spending all his time entertaining, and having been married and divorced three times. Sabrina Fairchild is the young, shy, and awkward daughter of the household chauffeur, who has been infatuated with David all her life, but whom David hardly notices till she goes away to Paris for two years and returns an elegant, sophisticated, beautiful woman. Suddenly, she finds she's captured David's attention, but just as she does so, she finds herself also falling in love with Linus, and she finds that Linus is also falling in love with her.", 'Language': 'English, French', 'Country': 'United States', 'Awards': 'Won 1 Oscar. 7 wins & 8 nominations total', 'Poster': 'https://m.media-amazon.com/images/M/MV5BYmFlNTA1NWItODQxNC00YjFmLWE3ZWYtMzg3YTkwYmMxMjY2XkEyXkFqcGdeQXVyMTMxMTY0OTQ@._V1_SX300.jpg', 'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.7/10'}, {'Source': 'Rotten Tomatoes', 'Value': '93%'}, {'Source': 'Metacritic', 'Value': '72/100'}], 'Metascore': '72', 'imdbRating': '7.7', 'imdbVotes': '60,674', 'imdbID': 'tt0047437', 'Type': 'movie', 'DVD': '06 Jun 2014', 'BoxOffice': 'N/A', 'Production': 'Paramount Pictures', 'Website': 'N/A', 'Response': 'True'}
# Sabrina

# %%
#clear and create imdb df
imdb_df = a[0:0]
imdb_df
# Out:
# Empty DataFrame
# Columns: [Title, Year, Rated, Released, Runtime, Genre, Director, Writer, Actors, Plot, Language, Country, Awards, Poster, Ratings, Metascore, imdbRating, imdbVotes, imdbID, Type, DVD, BoxOffice, Production, Website, Response]
# Index: []

# %%
#iterate movie dataframe to obtain imdbID
#------------------------------------------------------
import math

for i, row in movies_edited.iterrows():
    imdbID = row['imdbID']
    print(imdbID)
    if str(imdbID) == 'nan' :
        continue
        
    url2 = "http://www.omdbapi.com/?i="+imdbID+"&plot=full&apikey="+API_KEY

    r = requests.get(url2)
    jsonA = r.json()


    if (jsonA['Response']=='False'):
        print("------------------------------Error occur for " + imdbID)
    else:
            print (jsonA['Title'])
            a = pd.DataFrame(jsonA)
            pd.set_option('display.max_columns', 30)
            a = a.drop(columns="Ratings") 
            a.drop_duplicates(inplace=True)
            imdb_df = imdb_df.append(a,ignore_index = True)
# Out:
# tt0116477
# Hamlet
# tt0118002
# Two If by Sea
# tt0113097
# Forget Paris
# tt0113501
# Just Cause
# tt0114268
# Rent-a-Kid
# tt3622592
# Paper Towns
# tt5973164
# Fearless
# tt0107497
# Malice
# tt0117108
# Multiplicity
# tt0117628
# She's the One
# tt11163028
# House Arrest
# tt0039420
# The Ghost and Mrs. Muir
# tt0115580
# The Associate
# tt0112896
# Dracula: Dead and Loving It
# tt0114011
# Now and Then
# tt0117102
# Mr. Wrong
# tt0111194
# A Simple Twist of Fate
# tt0104029
# Cronos
# tt0117283
# The Pallbearer
# tt0111667
# The War
# tt0116126
# Don't Be a Menace to South Central While Drinking Your Juice in the Hood
# tt0115472
# The Adventures of Pinocchio
# tt0116240
# The Evening Star
# tt0119815
# Four Days in September
# tt0113670
# A Little Princess
# tt1815708
# Freelancers
# tt0085809
# Koyaanisqatsi
# tt0112453
# Balto
# tt0115734
# Bottle Rocket
# tt0114808
# The Star Maker
# tt5580392
# Amateur
# tt0113677
# Living in Oblivion
# tt0114095
# Party Girl
# tt0114210
# A Pyromaniac's Love Story
# tt0111149
# Shallow Grave
# tt0110950
# Reality Bites
# tt0110455
# A Man of No Importance
# tt0110763
# The Pagemaster
# tt0110395
# Love and a .45
# tt0095776
# Oliver & Company
# tt0116707
# Joe's Apartment
# tt0109485
# Celestial Clockwork
# tt0115994
# Curdled
# tt0116293
# Female Perversions
# tt0115495
# Albino Alligator
# tt0112373
# Anne Frank Remembered
# tt0115837
# Carried Away
# tt0113443
# It's My Party
# tt0112536
# Bloodsport 2
# tt0119013
# Double Team
# tt0120179
# Speed 2: Cruise Control
# tt0108162
# Sliver
# tt0076538
# Pete's Dragon
# tt0116059
# Dear God
# tt0113674
# Live Nude Girls
# tt0117891
# A Thin Line Between Love and Hate
# tt0116531
# High School High
# tt0115927
# Commandments
# tt0113247
# La Haine
# tt0116324
# Flirting with Disaster
# tt0110769
# Red Firecracker, Green Firecracker
# tt0111689
# What Happened Was...
# tt0108149
# Six Degrees of Separation
# tt0118001
# Two Much
# tt5664952
# Trust
# tt0103905
# Man Bites Dog
# tt0120670
# Firestorm
# tt0120769
# The Newton Boys
# tt0112495
# Beyond Rangoon
# tt0113044
# Feast of July
# tt0109579
# Death and the Maiden
# tt0114614
# Tank Girl
# tt0109655
# Double Happiness
# tt0109450
# Cobb
# tt0110588
# Mrs. Parker and the Vicious Circle
# tt0116269
# Faithful
# tt0117991
# Twelfth Night or What You Will
# tt0032762
# The Mark of Zorro
# tt0117791
# Surviving Picasso
# tt0078446
# Up in Smoke
# tt0094006
# Some Kind of Wonderful
# tt0116601
# I'm Not Rappaport
# tt0058450
# The Umbrellas of Cherbourg
# tt0032022
# They Made Me a Criminal
# tt0047162
# The Last Time I Saw Paris
# tt0022879
# A Farewell to Arms
# tt8021824
# The Innocents
# tt0052027
# The Old Man and the Sea
# tt0120382
# The Truman Show
# tt0113283
# Heidi Fleiss: Hollywood Madam
# tt0109424
# Chungking Express
# tt0110217
# Jupiter's Wife
# tt7902072
# Safe
# tt0116289
# Feeling Minnesota
# tt0072951
# Escape to Witch Mountain
# tt0116404
# Get on the Bus
# tt0101761
# The Doors
# tt0116410
# Ghosts of Mississippi
# tt0115640
# Beautiful Thing
# tt0118702
# Best Men
# tt0113243
# Hackers
# tt0111001
# The Road to Wellville
# tt3832914
# War Room
# tt0118147
# When We Were Kings
# tt0119256
# Hard Eight
# tt7193218
# The Quiet Room
# tt0109305
# Blue Chips
# tt0106505
# Calendar Girl
# tt0257315
# My Family
# tt0111454
# Tom & Viv
# tt0067959
# Walkabout
# tt0116827
# Last Dance
# tt0117260
# Original Gangstas
# tt0116621
# In Love and War
# tt0106339
# Backbeat
# tt0058898
# Alphaville
# tt0114266
# Rendezvous in Paris
# tt0112767
# Cyclo
# tt0120004
# The Relic
# tt0113057
# A Single Girl
# tt0079944
# Stalker
# tt0119578
# Love! Valour! Compassion!
# tt0117284
# Palookaville
# tt0117332
# Phat Beach
# tt8613070
# Portrait of a Lady on Fire
# tt0120550
# Zeus and Roxanne
# tt0115676
# Big Bully
# tt0107447
# Love & Human Remains
# tt0111309
# The Sum of Us
# tt0107426
# Little Buddha
# tt0109842
# Fresh
# tt0111252
# Spanking the Monkey
# tt0111019
# Wild Reeds
# tt0032143
# The Women
# tt9026524
# Bliss
# tt5596468
# Caught
# tt0119327
# Hugo Pool
# tt0120490
# Welcome to Sarajevo
# tt0116151
# Dunston Checks In
# tt0110443
# Major Payne
# tt0331933
# Man of the House
# tt0110093
# I Love Trouble
# tt0110399
# A Low Down Dirty Shame
# tt0109480
# Cops and Robbersons
# tt0109493
# The Cowboy Way
# tt0109729
# The Endless Summer 2
# tt0110123
# In the Army Now
# tt0110137
# The Inkwell
# tt0073778
# Maggie's Stiletto Sisters
# tt0100994
# Young Guns II
# tt0119937
# Prefontaine
# tt0120318
# That Old Feeling
# tt0119521
# A Letter from Death Row
# tt0106473
# The Boys of St. Vincent
# tt0110882
# Before the Rain
# tt0110729
# Once Were Warriors
# tt0106966
# Strawberry and Chocolate
# tt0105032
# Savage Nights
# tt0116275
# A Family Thing
# tt0054189
# Purple Noon
# tt0109592
# Cemetery Man
# tt0042644
# Kim
# tt0116992
# Marlene Dietrich: Shadow and Light
# tt0109255
# Maybe... Maybe Not
# tt0027125
# Top Hat
# tt0035446
# To Be or Not to Be
# tt0058846
# Secret Agent
# tt0106266
# Amos & Andrew
# tt0113451
# Jade
# tt0039536
# Kiss of Death
# tt0110538
# Mixed Nuts
# tt0114857
# Virtuosity
# tt0109306
# Blue Sky
# tt3507484
# Flesh and Bone
# tt0107057
# Guilty as Sin
# tt0074102
# In the Realm of the Senses
# tt0115624
# Barb Wire
# tt0116783
# Kissed
# tt0112401
# Assassins
# tt0113118
# Friday
# tt0113198
# A Goofy Movie
# tt0113305
# Higher Learning
# tt0111693
# When a Man Loves a Woman
# tt0107286
# Judgment Night
# tt0118375
# King of the Hill
# tt0111094
# The Scout
# tt0112368
# Angus
# tt0119783
# Night Falls on Manhattan
# tt0112427
# An Awfully Big Adventure
# tt0114781
# Under Siege 2: Dark Territory
# tt0114151
# Poison Ivy II
# tt0110907
# Ready to Wear
# tt0100114
# Marked for Death
# tt0102370
# Madonna: Truth or Dare
# tt0117221
# Nenette and Boni
# nm0000069
# ------------------------------Error occur for nm0000069
# tt0898266
# The Big Bang Theory
# tt0119845
# Other Voices, Other Rooms
# tt0117994
# Twisted
# tt0118230
# Full Speed
# tt0112760
# Cutthroat Island
# tt0113568
# Ghost in the Shell
# tt0118064
# The Van
# tt0103207
# The Old Lady Who Walked in the Sea
# tt0480256
# Night Fliers
# tt0119664
# Metro
# tt0119225
# Gridlock'd
# tt0112602
# Bushwhacked
# tt0109198
# Bad Girls
# tt0109297
# Blink
# tt0106941
# For Love or Money
# tt0112483
# Best of the Best 3: No Turning Back
# tt0117050
# A Chef in Love
# tt0057345
# Contempt
# tt9014060
# ------------------------------Error occur for tt9014060
# tt0119214
# Gone Fishin'
# tt0772157
# Broken English
# tt0118964
# The Designated Mourner
# tt0118964
# The Designated Mourner
# tt5511512
# Trial & Error
# tt0106102
# Pie in the Sky
# tt0114702
# Total Eclipse
# tt0114307
# The Run of the Country
# tt0118113
# Walking and Talking
# tt0116353
# Foxfire
# tt0119807
# Nothing to Lose
# tt0120197
# Star Maps
# tt0070506
# Bread and Chocolate
# tt0112688
# Clockers
# tt0104779
# Bitter Moon
# tt0050658
# Love in the Afternoon
# tt0107413
# Life with Mikey
# tt0110687
# North
# tt0111357
# Talking About Sex
# tt0109456
# Color of Night
# tt0107978
# RoboCop 3
# tt0110259
# Killer
# tt0117784
# Sunset Park
# tt0117603
# Set It Off
# tt0120094
# Selena
# tt0120512
# Wild America
# tt2719784
# Gang Related
# tt0116985
# Manny & Lo
# tt0113211
# The Grass Harp
# tt0119848
# Out to Sea
# tt0115645
# Before and After
# tt0110892
# Princess Caraboo
# tt0358135
# Shall We Dance
# tt0116165
# Ed
# tt0112844
# Denise Calls Up
# tt0113448
# Jack & Sarah
# tt0109491
# Country Life
# tt0115851
# Celtic Pride
# tt0120133
# A Simple Wish
# tt0120478
# Star Kid
# tt0118662
# Ayn Rand: A Sense of Life
# tt0119457
# Kicked in the Head
# tt0107212
# Indian Summer
# tt0110391
# Love Affair
# tt0045537
# The Band Wagon
# tt0034012
# Penny Serenade
# tt0118523
# 'Til There Was You
# tt0083131
# Stripes
# tt1572502
# Late Bloomers
# tt0109890
# The Getaway
# tt0117169
# New York Cop
# tt0113936
# Senior Trip
# tt0109593
# Delta of Venus
# tt0109381
# Carmen Miranda: Bananas Is My Business
# tt0109191
# Babyfever
# tt0072362
# A Very Natural Thing
# tt0038235
# A Walk in the Sun
# tt0114885
# Waiting to Exhale
# tt0117357
# The Pompatus of Love
# tt0120782
# Palmetto
# tt0111323
# Surviving the Game
# tt0119381
# Inventing the Abbotts
# tt0119314
# The Horse Whisperer
# tt0113490
# The Journey of August King
# tt0103384
# Catwalk
# tt0113952
# The Neon Bible
# tt0113319
# Homage
# tt0400717
# Open Season
# tt0107642
# Café au lait
# tt0111752
# Wu Kui
# tt6210192
# Loaded
# tt0115591
# August
# tt0115742
# Boys
# tt2326612
# The Captive
# tt0110712
# Of Love and Shadows
# tt7012864
# Lowlife
# tt0111546
# An Unforgettable Summer
# tt0113610
# The Last Klezmer: Leopold Kozlowski, His Life and Music
# tt0106810
# En compagnie d'Antonin Artaud
# tt0111180
# Midnight Dancers
# tt0111237
# Somebody to Love
# tt0115530
# American Buffalo
# tt0116756
# Kazaam
# tt0116823
# Larger Than Life
# tt0117999
# Two Deaths
# tt0108220
# Stefano Quantestorie
# tt0112746
# The Crude Oasis
# tt0104403
# Hedd Wyn
# tt9367692
# The Convenient Truth
# tt0113695
# Lotto Land
# tt0108227
# Xinghua san yue tian
# tt0111424
# The Day the Sun Turned Cold
# tt0104109
# Dingo
# tt0084390
# The Ballad of Narayama
# tt6111598
# ------------------------------Error occur for tt6111598
# tt0107575
# Mille bolle blu
# tt0042054
# Crows and Sparrows
# tt0116934
# Lover's Knot
# tt0075169
# Shadow of Angels
# tt0109001
# 1-900
# tt0105729
# Venice/Venice
# tt0116635
# Infinity
# tt0116167
# Ed's Next Move
# tt0109823
# For the Moment
# tt0645145
# The Deadly Cure
# tt5144366
# 7 Days in Venice Beach
# tt0111622
# The Sex Life of the Belgians
# tt0117577
# The Search for One-eye Jimmy
# tt0115531
# American Strays
# tt0116859
# The Leopard Son
# tt7245458
# Bird of Prey
# tt0107274
# Johnny One Hundred Pesos
# tt0110173
# JLG/JLG: Self-Portrait in December
# tt0109781
# Lesson Faust
# tt0110521
# Mina Tannenbaum
# tt0042354
# The Forbidden Christ
# tt0110171
# I Can't Sleep
# tt0110425
# La machine
# tt0123281
# The Stranger
# tt0067152
# Good Morning
# tt0080714
# Falling in Love Again
# tt0106535
# The Cement Garden
# tt0119644
# Meet Wally Sparks
# tt0116565
# Hotel de Love
# tt0120014
# Rhyme & Reason
# tt0116931
# Love and Other Catastrophes
# tt0113314
# Hollow Reed
# tt0116920
# Losing Chase
# tt0058985
# Le Bonheur
# tt0120087
# The Second Jungle Book: Mowgli & Baloo
# tt0117724
# Squeeze
# tt0120034
# Roseanna's Grave
# tt0105569
# Tetsuo II: Body Hammer
# tt0119098
# Fall
# tt0116384
# Gabbeh
# tt0117076
# Mondo
# tt0113425
# The Innocent Sleep
# tt0116334
# For Ever Mozart
# tt0119557
# The Locusts
# tt4845906
# Stag
# tt0120257
# Amy Foster
# tt0119338
# Hurricane Streets
# tt3018070
# Stonewall
# tt0025586
# Of Human Bondage
# tt7456310
# Anna
# tt0120222
# Stranger in the House
# tt0114129
# Picture Bride
# tt0107468
# M. Butterfly
# tt0107225
# Ciao, Professore!
# tt0109382
# Dear Diary
# tt0094336
# Withnail & I
# tt0118762
# Boys Life 2
# tt0114916
# When Night Is Falling
# tt0111255
# The Specialist
# tt0113199
# Gordy
# tt0111333
# The Swan Princess
# nan
# tt0062711
# Barbarella
# tt0113596
# The Land Before Time III: The Time of the Great Giving
# tt0111301
# Street Fighter
# tt0112702
# Coldblooded
# tt0110657
# The Next Karate Kid
# tt1781922
# No Escape
# tt7510346
# The Turning
# tt0107282
# The Joy Luck Club
# tt0110027
# Highlander: The Final Dimension
# tt0568382
# Gilligan's Island: The Untold Tales
# tt0107566
# Mi vida loca
# tt0108260
# Suture
# tt1520211
# The Walking Dead
# tt0110091
# I Like It Like That
# tt0110097
# I'll Do Anything
# tt0116442
# Grace of My Heart
# tt0112907
# Drunks
# tt0086589
# Suburbia
# tt0120148
# Sliding Doors
# tt0119352
# Ill Gotten Gains
# tt0130073
# Legal Deceit
# tt0119670
# The Mighty
# tt0119655
# Men of Means
# tt0120122
# Shooting Fish
# tt0114536
# Steal Big Steal Little
# tt6828390
# Mr. Jones
# tt0110064
# House Party 3
# tt0114084
# Panther
# tt0110186
# Jason's Lyric
# tt0109035
# Above the Rim
# tt0113851
# Moonlight and Valentino
# tt0114345
# The Scarlet Letter
# tt0109021
# 8 Seconds
# tt0059793
# That Darn Cat!
# tt0110296
# Ladybird Ladybird
# tt2639596
# Bye Bye, Love
# tt0106537
# Century
# tt0107471
# My Favorite Season
# tt0048473
# Pather Panchali
# tt0039428
# Golden Earrings
# tt0032484
# Foreign Correspondent
# tt0036094
# Lady of Burlesque
# tt0038300
# Angel on My Shoulder
# tt0039152
# Angel and the Badman
# tt6679794
# Outlaw King
# tt0046414
# Beat the Devil
# tt0116928
# Love Is All There Is
# tt0028757
# A Damsel in Distress
# tt0023169
# Madame Butterfly
# tt0368975
# Sleepover
# tt0026465
# Here Comes Cookie
# tt0118100
# Thieves
# tt0118764
# Les Boys
# tt0114534
# The Stars Fell on Henrietta
# tt0113612
# Last Summer in the Hamptons
# tt0113774
# Margaret's Museum
# tt0108026
# The Saint of Fort Washington
# tt0112757
# The Cure
# tt0112302
# Tom and Huck
# tt0113234
# Gumby: The Movie
# tt0113303
# Hideaway
# tt0108500
# The Visitors
# tt0113670
# A Little Princess
# tt0110671
# Nina Takes a Lover
# tt0106408
# Bhaji on the Beach
# tt0091828
# Raw Deal
# tt0119791
# Nightwatch
# tt0112819
# Dead Presidents
# tt2726196
# Reckless
# tt0071607
# Herbie Rides Again
# tt0111048
# S.F.W.
# tt0113147
# The Gate of Heavenly Peace
# tt0120744
# The Man in the Iron Mask
# tt0110189
# The Jerky Boys
# tt0109454
# Colonel Chabert
# tt0113173
# Girl in the Cadillac
# tt0106834
# Even Cowgirls Get the Blues
# tt0107002
# Germinal
# tt0109403
# Chasers
# tt0223268
# Faust
# tt0114706
# Tough and Deadly
# tt0110719
# Window to Paris
# tt0113839
# A Modern Affair
# tt0076411
# Il mostro
# tt0113080
# Flirt
# tt0115836
# Carpool
# tt2147657
# Al Hirschfeld: The Line King
# tt0113031
# Farmer & Chase
# tt0109942
# Dead Tired
# tt0117550
# Santa with Muscles
# tt0116754
# Prisoner of the Mountains
# tt0110623
# Naked in New York
# tt0113188
# Gold Diggers: The Secret of Bear Mountain
# tt0109255
# Maybe... Maybe Not
# tt0113542
# Killer: A Journal of Murder
# tt0113947
# Nelly & Monsieur Arnaud
# tt0117968
# Three Lives and Only One Death
# tt4225622
# The Babysitter
# tt0109891
# Getting Even with Dad
# tt0116953
# Mad Dog Time
# tt0115886
# Children of the Revolution
# tt0052572
# The World of Apu
# tt0120190
# Sprung
# tt0119019
# Dream with the Fishes
# tt0114952
# Wings of Courage
# tt0893566
# Wedding Gift
# tt0117427
# Race the Sun
# tt0113691
# Losing Isaiah
# tt0113967
# New Jersey Drive
# tt0113043
# The Fear
# tt0107613
# Mr. Wonderful
# tt0111488
# Trial by Jury
# tt0109920
# A Good Man in Africa
# tt0110246
# Kaspar Hauser
# tt0120772
# The Object of My Affection
# tt0090329
# Witness
# tt0120820
# Senseless
# tt0119809
# Nowhere
# tt0114787
# Underground
# tt0113463
# Jefferson in Paris
# tt0113028
# Far from Home: The Adventures of Yellow Dog
# tt0109828
# Foreign Student
# tt0106678
# I Don't Want to Talk About It
# tt0120394
# Twin Town
# tt0109731
# L'Enfer
# tt0109066
# Vive L'Amour
# tt0115951
# Cosi
# tt0118586
# All Over Me
# tt1349938
# Being Human
# tt0112342
# The Amazing Panda Adventure
# tt0109226
# The Beans of Egypt, Maine
# tt0114345
# The Scarlet Letter
# tt0116714
# Johns
# tt0113442
# It Takes Two
# tt0113107
# Frankie Starlight
# tt0094878
# Cienie
# tt0114435
# The Show
# tt0112727
# The Courtyard
# tt0112899
# Dream Man
# tt0112854
# Destiny Turns on the Radio
# tt0109906
# The Glass Shield
# tt0113360
# The Hunted
# tt0114788
# The Underneath
# tt0111054
# Safe Passage
# tt0108069
# The Secret Adventures of Tom Thumb
# tt0112712
# Condition Red
# tt0111787
# Yankee Zulu
# tt0048956
# Aparajito
# tt0110061
# Hostile Intentions
# tt0082206
# Coup de Torchon
# tt0111430
# Tigrero: A Film That Was Never Made
# tt0107727
# L'oeil de Vichy
# tt4552298
# Killing for Love
# tt0103095
# To Cross the Rubicon
# tt0104046
# Daens
# tt0031612
# The Man from Down Under
# tt0103926
# Careful
# tt0105737
# Vermont Is for Lovers
# tt0094265
# Life Is Rosy
# tt0105201
# Quartier Mozart
# tt0070820
# Journey of the Hyena
# tt0084898
# Wend Kuuni
# tt0063715
# Spirits of the Dead
# tt0114122
# Pharaoh's Army
# tt0100990
# I, the Worst of All
# tt0093199
# A Hungarian Fairy Tale
# tt0049521
# Death in the Garden
# tt0061495
# La Collectionneuse
# tt0094822
# Baton Rouge
# tt0024252
# Liebelei
# tt1098459
# The Woman in Question
# tt0039881
# T-Men
# tt2400463
# The Invitation
# tt3697948
# Symphonie Pastorale
# tt0099028
# American Dream
# tt0104684
# Hard Boiled
# tt0052287
# Terror in a Texas Town
# tt0117544
# Hi Cousin!
# tt0117561
# Schizopolis
# tt0112951
# En avoir (ou pas)
# tt0112913
# Fallen Angels
# tt2302701
# Magic Hour
# tt0101692
# Death in Brunswick
# tt0325332
# Everest: The Death Zone
# tt0111173
# Shopping
# tt0113948
# Nemesis 2: Nebula
# tt0105275
# Romper Stomper
# tt0118859
# City of Industry
# tt0114494
# Someone Else's America
# tt0109949
# Guantanamera
# tt0119819
# Office Killer
# tt0120793
# A Price Above Rubies
# tt0112364
# Angela
# tt0040427
# He Walked by Night
# tt0116930
# Love Serenade
# tt0119527
# Deceiver
# tt0119338
# Hurricane Streets
# tt0118787
# Buddy
# tt0118663
# B*A*P*S
# tt0120383
# Truth or Consequences, N.M.
# tt0116643
# Intimate Relations
# tt0116845
# The Leading Man
# tt0114690
# Tokyo Fist
# tt0052126
# The Reluctant Debutante
# tt0120479
# Warriors of Virtue
# tt0112849
# Desert Winds
# tt0119327
# Hugo Pool
# tt0099939
# King of New York
# tt0113720
# All Things Fair
# tt0120142
# The Sixth Man
# tt0112604
# Butterfly Kiss
# tt0107779
# Paris, France
# tt0112769
# La Cérémonie
# tt5022702
# Hush
# tt0119791
# Nightwatch
# tt0110251
# Nobody Loves Me
# tt0114936
# The Wife
# tt0110299
# Lamerica
# tt0113973
# Nico Icon
# tt0111055
# The Silences of the Palace
# tt0410626
# Slingshot
# tt0114671
# Land and Freedom
# tt0109028
# Cold Fever
# tt0109751
# Under the Domim Tree
# tt0092123
# 2 Friends
# tt0112586
# Brothers in Trouble
# tt0052850
# Girls Town
# tt0117202
# Normal Life
# tt0115600
# Bitter Sugar
# tt0116581
# The Eighth Day
# tt0112777
# Dadetown
# tt0117690
# Some Mother's Son
# tt0054628
# Angel Baby
# tt0117775
# Sudden Manhattan
# tt0118804
# The Butcher Boy
# tt0119657
# Men with Guns
# tt0119250
# Fireworks
# tt0119780
# Niagara, Niagara
# tt0080437
# The Big Red One
# tt0118804
# The Butcher Boy
# tt0120176
# The Spanish Prisoner
# tt0116295
# Temptress Moon
# tt0116212
# Entertaining Angels: The Dorothy Day Story
# tt0118836
# Chairman of the Board
# tt0109783
# The Favor
# tt0119548
# Little City
# tt0114618
# Target
# tt0117773
# The Substance of Fire
# tt0116405
# Getting Away with Murder
# tt0114474
# Small Faces
# tt0110649
# The New Age
# tt0114303
# Rough Magic
# tt1320352
# Nothing Personal
# tt0118541
# 8 Heads in a Duffel Bag
# tt0118783
# A Brother's Kiss
# tt0117482
# Ripe
# tt2374744
# The Next Step
# tt0118127
# Wedding Bell Blues
# tt0116949
# MURDER and murder
# tt3952864
# ------------------------------Error occur for tt3952864
# tt0116379
# The Break
# tt0107315
# Kika
# tt0113827
# Mirage
# tt0056215
# Mamma Roma
# tt0117781
# The Sunchaser
# tt0460692
# The War at Home
# tt0114592
# Sweet Nothing
# tt0119711
# Mother and Son
# tt0120594
# B. Monkey
# tt0120148
# Sliding Doors
# tt0111804
# Martin Lawrence: You So Crazy
# tt0102855
# Scream of Stone

# %%
imdb_df.drop_duplicates(inplace=True)
imdb_df.head(10)
# Out:
#                                               Actors  \
# 0      Tom Hanks, Tim Allen, Don Rickles, Jim Varney
# 1  Pierce Brosnan, Sean Bean, Izabella Scorupco, ...
# 2  Sammi Davis, Amanda De Cadenet, Valeria Golino...
# 3  Carolyn Dodd, Goya Robles, Sean Bridgers, Isaa...
# 4  Sigourney Weaver, Holly Hunter, Dermot Mulrone...
# 5     Li Gong, Baotian Li, Xiaoxiao Wang, Xuejian Li
# 6  Joseph Melito, Bruce Willis, Jon Seda, Michael...
# 7  Christine Cavanaugh, Miriam Margolyes, Danny M...
# 8  Susan Sarandon, Sean Penn, Robert Prosky, Raym...
# 9  Christopher Bowen, Edward Jewesbury, Ian McKel...
#
#                                               Awards BoxOffice  \
# 0  Nominated for 3 Oscars. Another 26 wins & 20 n...       N/A
# 1  Nominated for 2 BAFTA Film Awards. Another 2 w...       N/A
# 2                              1 win & 1 nomination.       N/A
# 3                                      1 nomination.       NaN
# 4                             2 wins & 1 nomination.       N/A
# 5  Nominated for 1 Oscar. Another 5 wins & 3 nomi...       N/A
# 6  Nominated for 2 Oscars. Another 10 wins & 22 n...       N/A
# 7     Won 1 Oscar. Another 19 wins & 26 nominations.       N/A
# 8     Won 1 Oscar. Another 22 wins & 21 nominations.       N/A
# 9  Nominated for 2 Oscars. Another 7 wins & 10 no...       N/A
#
#           Country          DVD  \
# 0             USA  20 Mar 2001
# 1         UK, USA  19 Oct 1999
# 2             USA  20 Apr 1999
# 3             USA          NaN
# 4             USA  28 Apr 1998
# 5   France, China  12 Dec 2000
# 6             USA  31 Mar 1998
# 7  Australia, USA  23 Sep 2003
# 8         UK, USA  30 Sep 1998
# 9         UK, USA  15 Aug 2001
#
#                                             Director Episode  \
# 0                                      John Lasseter     NaN
# 1                                    Martin Campbell     NaN
# 2  Allison Anders, Alexandre Rockwell, Robert Rod...     NaN
# 3                                      Allen Coulter     NaN
# 4                                          Jon Amiel     NaN
# 5                                        Yimou Zhang     NaN
# 6                                      Terry Gilliam     NaN
# 7                                       Chris Noonan     NaN
# 8                                        Tim Robbins     NaN
# 9                                  Richard Loncraine     NaN
#
#                                            Genre                   Language  \
# 0  Animation, Adventure, Comedy, Family, Fantasy                    English
# 1                    Action, Adventure, Thriller  English, Russian, Spanish
# 2                                         Comedy                    English
# 3                                  Comedy, Crime                    English
# 4                       Drama, Mystery, Thriller                    English
# 5       Crime, Drama, History, Romance, Thriller                   Mandarin
# 6                      Mystery, Sci-Fi, Thriller            English, French
# 7                          Comedy, Drama, Family                    English
# 8                                   Crime, Drama                    English
# 9                             Drama, Sci-Fi, War                    English
#
#   Metascore                                               Plot  \
# 0        95  A little boy named Andy loves to be in his roo...
# 1        65  When a deadly satellite weapon system falls in...
# 2       N/A  This movie features the collaborative director...
# 3       N/A  The adventures of a mobster-turned-movie produ...
# 4        54  In San Francisco, the criminal psychologist He...
# 5       N/A  Uncle Liu brings his cousin to Shanghai to wor...
# 6        74  An unknown and lethal virus has wiped out five...
# 7        83  Gentle farmer Arthur Hoggett wins a piglet nam...
# 8        80  A convicted murderer on Death Row and the nun ...
# 9       N/A  William Shakespeare's classic play is brought ...
#
#                                               Poster  \
# 0  https://m.media-amazon.com/images/M/MV5BMDU2ZW...
# 1  https://m.media-amazon.com/images/M/MV5BMzk2OT...
# 2  https://m.media-amazon.com/images/M/MV5BNDc3Y2...
# 3  https://m.media-amazon.com/images/M/MV5BMTExMT...
# 4  https://m.media-amazon.com/images/M/MV5BYWUwND...
# 5  https://m.media-amazon.com/images/M/MV5BYjQ0OT...
# 6  https://m.media-amazon.com/images/M/MV5BN2Y2OW...
# 7  https://m.media-amazon.com/images/M/MV5BYjg4Zj...
# 8  https://m.media-amazon.com/images/M/MV5BMTM3Nz...
# 9  https://m.media-amazon.com/images/M/MV5BOWI3Nj...
#
#                          Production  Rated     Released Response  Runtime  \
# 0                       Buena Vista      G  22 Nov 1995     True   81 min
# 1                            MGM/UA  PG-13  17 Nov 1995     True  130 min
# 2                     Miramax Films      R  25 Dec 1995     True   98 min
# 3                               NaN  TV-MA          N/A     True   60 min
# 4                 Warner Home Video      R  27 Oct 1995     True  123 min
# 5  Sony Pictures Home Entertainment      R  22 Dec 1995     True  108 min
# 6                Universal Pictures      R  05 Jan 1996     True  129 min
# 7                Universal Pictures      G  04 Aug 1995     True   91 min
# 8                 Gramercy Pictures      R  02 Feb 1996     True  122 min
# 9                    United Artists      R  29 Dec 1995     True  110 min
#
#   Season             Title    Type Website  \
# 0    NaN         Toy Story   movie     N/A
# 1    NaN         GoldenEye   movie     N/A
# 2    NaN        Four Rooms   movie     N/A
# 3    NaN        Get Shorty  series     NaN
# 4    NaN           Copycat   movie     N/A
# 5    NaN    Shanghai Triad   movie     N/A
# 6    NaN        12 Monkeys   movie     N/A
# 7    NaN              Babe   movie     N/A
# 8    NaN  Dead Man Walking   movie     N/A
# 9    NaN       Richard III   movie     N/A
#
#                                               Writer   Year     imdbID  \
# 0  John Lasseter (original story by), Pete Docter...   1995  tt0114709
# 1  Ian Fleming (characters), Michael France (stor...   1995  tt0113189
# 2  Allison Anders, Alexandre Rockwell, Robert Rod...   1995  tt0113101
# 3                                       Davey Holmes  2017–  tt5761496
# 4                         Ann Biderman, David Madsen   1995  tt0112722
# 5                          Bi Feiyu, Li Xiao (novel)   1995  tt0115012
# 6  Chris Marker (film La Jetée), David Webb Peopl...   1995  tt0114746
# 7  Dick King-Smith (novel), George Miller (screen...   1995  tt0112431
# 8                  Helen Prejean (book), Tim Robbins   1995  tt0112818
# 9  William Shakespeare (play), Ian McKellen, Rich...   1995  tt0114279
#
#   imdbRating imdbVotes seriesID totalSeasons
# 0        8.3   830,337      NaN          NaN
# 1        7.2   227,904      NaN          NaN
# 2        6.8    93,243      NaN          NaN
# 3        8.2     4,340      NaN            3
# 4        6.6    51,161      NaN          NaN
# 5        7.1     4,868      NaN          NaN
# 6        8.0   551,055      NaN          NaN
# 7        6.7   111,602      NaN          NaN
# 8        7.5    84,294      NaN          NaN
# 9        7.4    13,170      NaN          NaN

# %%
imdb_df.to_csv ('processed-data/imdb_df.csv', index = None, header=True,encoding='utf-8-sig')

# %% [markdown]
# ## Combine the movie file and imdb file

# %%
combine = pd.merge(movies_edited,imdb_df)
combine.to_csv ('processed-data/combine.csv', index = None, header=True,encoding='utf-8-sig')
combine.head()
